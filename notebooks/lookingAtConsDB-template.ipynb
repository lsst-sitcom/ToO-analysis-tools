# %% [markdown]
# Owner: **Sean MacBride** [@seanmacb](https://github.com/seanmacb/) <br>
# Adapted from a notebook from **Chris  Suberlak** [@suberlak](https://github.com/lsst-ts/ts_aos_analysis/issues/new?body=@suberlak) <br>
# Last Verified to Run: **2025-08-19** <br>
# <!-- Software Versions:
#   - `lsst_distrib`: **w_2025_45** -->
#
# ## Setup:
#
# This notebook was run on https://usdf-rsp.slac.stanford.edu/ .  The only necessary step required to access `consDB` is to remove the `HTTP_PROXY` environmental variable if present, with eg. `del os.environ["http_proxy"]`.
#
# The Engineering Facilities Database, or EFD, contains fine-grained telemetry from a variety of sensors and instruments, such as
# force balance offsets (hardpoint correction), applied forces (sum of all above + AOS closed-loop corrections). For example [this movie](https://rubin-obs.slack.com/archives/C07QM715AJY/p1718056301907499) was prepared with the EFD data by C. Lage.
#
#
# ConsDB generally contains exposure-level  aggregate information, i.e. either information already present in the header of each exposure,  or  in the "Transformed EFD" portion of the ConsDB,  the aggregate  of the time-series EFD data over the exposure time window with the ["EFD Transformation service".](https://rubin-obs.slack.com/archives/C07QJMQ7L4A/p1716317310421029?thread_ts=1716315549.132149&cid=C07QJMQ7L4A)

# %%
from astropy.time import Time, TimeDelta
import pandas as pd
from lsst.summit.utils.efdUtils import getEfdData, makeEfdClient
from lsst.daf import butler as dafButler
import lsst.summit.utils.butlerUtils as butlerUtils
from lsst.summit.utils import ConsDbClient
from lsst.summit.utils.utils import computeCcdExposureId
import os

# %% [markdown]
# ## Resources on consDB
#
# * A grafana page with up-to-date [consDB status](https://grafana.slac.stanford.edu/d/z7FCA4Nnk/cloud-native-postgresql-cnpg?orgId=1&refresh=30s&var-DataSource=940RXge4k&var-vcluster=vcluster--usdf-summitdb&var-cluster=summit-db-replica&var-instances=All&var-namespace=summit-db-replica&var-resolution=5m&from=now-24h&to=now)
#
# * Confluence page with documentation on [consDB access](https://rubinobs.atlassian.net/wiki/spaces/~ktl/pages/55377993/ConsDB+Usage)
#
# * [Schema browser](https://sdm-schemas.lsst.io/)
#
# * Tech-note on the [background for consDB](https://dmtn-227.lsst.io/)
#
# * [ConsDB transformed EFD topics](https://rubinobs.atlassian.net/wiki/spaces/DM/pages/48836130/Consolidated+Database+Transformed+EFD+Topics)

# %% [markdown]
# ## Connecting to consolidated database (consDB)

# %%
import os 
del os.environ["http_proxy"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 2
#       1 import os
# ----> 2 del os.environ["http_proxy"]
#
# File <frozen os>:730, in __delitem__(self, key)
#
# KeyError: 'http_proxy'

# %%
client = ConsDbClient('http://consdb-pq.consdb:8080/consdb')
print(f'schemas:\n', client.schema())
# Out:
# schemas:
#  ['latiss', 'lsstcam', 'lsstcamsim', 'lsstcomcam', 'lsstcomcamsim', 'startrackerfast', 'startrackernarrow', 'startrackerwide']

# %%
client = ConsDbClient('http://consdb-pq.consdb:8080/consdb')
print(client.schema())  # list the instruments
print(client.schema('lsstcam'))  # list tables for an instrument
# Out:
# ['latiss', 'lsstcam', 'lsstcamsim', 'lsstcomcam', 'lsstcomcamsim', 'startrackerfast', 'startrackernarrow', 'startrackerwide']
# ['cdb_lsstcam.ccdexposure_camera', 'cdb_lsstcam.ccdexposure', 'cdb_lsstcam.exposure', 'cdb_lsstcam.ccdvisit1_quicklook', 'cdb_lsstcam.visit1_quicklook', 'cdb_lsstcam.ccdexposure_flexdata', 'cdb_lsstcam.ccdexposure_flexdata_schema', 'cdb_lsstcam.ccdexposure_quicklook', 'cdb_lsstcam.exposure_flexdata', 'cdb_lsstcam.exposure_flexdata_schema', 'cdb_lsstcam.exposure_quicklook', 'cdb_lsstcam.visit1', 'cdb_lsstcam.ccdvisit1']

# %%
print(client.schema('lsstcam', 'cdb_lsstcam.ccdexposure_camera'))
# Out:
# {'ccdexposure_id': ('BIGINT', 'None'), 'temp_set': ('DOUBLE PRECISION', 'None'), 'ccd_temp': ('DOUBLE PRECISION', 'None')}

# %%
schema = 'lsstcam'
table = 'exposure'
print(f'columns (table={table}): {table} \n',
      list(client.schema('lsstcam', f'cdb_{schema}.{table}').keys()
          )
      )
# Out:
# columns (table=exposure): exposure
#  ['exposure_id', 'exposure_name', 'controller', 'day_obs', 'seq_num', 'physical_filter', 'band', 's_ra', 's_dec', 'sky_rotation', 'azimuth_start', 'azimuth_end', 'azimuth', 'altitude_start', 'altitude_end', 'altitude', 'zenith_distance_start', 'zenith_distance_end', 'zenith_distance', 'airmass', 'exp_midpt', 'exp_midpt_mjd', 'obs_start', 'obs_start_mjd', 'obs_end', 'obs_end_mjd', 'exp_time', 'shut_time', 'dark_time', 'group_id', 'cur_index', 'max_index', 'img_type', 'emulated', 'science_program', 'observation_reason', 'target_name', 'air_temp', 'pressure', 'humidity', 'wind_speed', 'wind_dir', 'dimm_seeing', 'focus_z', 'simulated', 'vignette', 'vignette_min', 's_region', 'scheduler_note', 'can_see_sky']

# %%
# https://rubin-obs.slack.com/archives/C07QJMQ7L4A/p1730392968242269?thread_ts=1730385376.310139&cid=C07QJMQ7L4A
# For investigating schema and table content 
client = ConsDbClient('http://consdb-pq.consdb:8080/consdb')
schema = 'lsstcam'
table = 'ccdvisit1_quicklook'
print(f'schemas:\n', client.schema())  # list the instruments
print(f'tables (schema={schema}):\n', client.schema(schema))  # list tables for an instrument
print(f'columns (table={table}): {table}\n', list(client.schema('lsstcam', f'cdb_{schema}.{table}').keys()))
# Out:
# schemas:
#  ['latiss', 'lsstcam', 'lsstcamsim', 'lsstcomcam', 'lsstcomcamsim', 'startrackerfast', 'startrackernarrow', 'startrackerwide']
# tables (schema=lsstcam):
#  ['cdb_lsstcam.ccdexposure_camera', 'cdb_lsstcam.ccdexposure', 'cdb_lsstcam.exposure', 'cdb_lsstcam.ccdvisit1_quicklook', 'cdb_lsstcam.visit1_quicklook', 'cdb_lsstcam.ccdexposure_flexdata', 'cdb_lsstcam.ccdexposure_flexdata_schema', 'cdb_lsstcam.ccdexposure_quicklook', 'cdb_lsstcam.exposure_flexdata', 'cdb_lsstcam.exposure_flexdata_schema', 'cdb_lsstcam.exposure_quicklook', 'cdb_lsstcam.visit1', 'cdb_lsstcam.ccdvisit1']
# columns (table=ccdvisit1_quicklook): ccdvisit1_quicklook
#  ['ccdvisit_id', 's_ra', 's_dec', 'zenith_distance', 'photometric_calib', 'psf_sigma', 'sky_bg', 'sky_noise', 'zero_point', 'seeing_zenith_500nm', 'pixel_scale', 'astrom_offset_mean', 'astrom_offset_std', 'eff_time', 'eff_time_psf_sigma_scale', 'eff_time_sky_bg_scale', 'eff_time_zero_point_scale', 'stats_mag_lim', 'mean_var', 'n_psf_star', 'psf_area', 'psf_ixx', 'psf_ixy', 'psf_iyy', 'psf_star_delta_e1_median', 'psf_star_delta_e2_median', 'psf_star_delta_e1_scatter', 'psf_star_delta_e2_scatter', 'psf_star_delta_size_median', 'psf_star_delta_size_scatter', 'psf_star_scaled_delta_size_scatter', 'psf_trace_radius_delta', 'psf_ap_flux_delta', 'psf_ap_corr_sigma_scaled_delta', 'max_dist_to_nearest_psf', 'z4', 'z5', 'z6', 'z7', 'z8', 'z9', 'z10', 'z11', 'z12', 'z13', 'z14', 'z15', 'z16', 'z17', 'z18', 'z19', 'z20', 'z21', 'z22', 'z23', 'z24', 'z25', 'z26', 'z27', 'z28']

# %%
day_obs = 20250728
query = f"""
SELECT e.band, e.exp_time, q.* 
from cdb_lsstcam.visit1_quicklook q, cdb_lsstcam.exposure e
where q.visit_id = e.exposure_id
and e.day_obs = {day_obs}
--order by e.seq_num desc
"""
df = client.query(query)
#df.columns
#df[['visit_id', 'eff_time_median', 'eff_time_sky_bg_scale_median', 'eff_time_psf_sigma_scale_median', 'eff_time_zero_point_scale_median']]
df[['visit_id', 'band', 'psf_sigma_median', 'sky_bg_median', 'zero_point_median']][:5]
# Out:
# <Table length=5>
#    visit_id   band psf_sigma_median sky_bg_median zero_point_median
#     int64     str1      object          object          object
# ------------- ---- ---------------- ------------- -----------------
# 2025072800004    r             None          None              None
# 2025072800005    r             None          None              None
# 2025072800006    r             None          None              None
# 2025072800007    r             None          None              None
# 2025072800008    r             None          None              None

# %%
query = f"""
SELECT v.band, v.exp_time, q.*
from cdb_lsstcam.visit1_quicklook q, cdb_lsstcam.visit1 v
where q.visit_id = v.visit_id
and v.day_obs = {day_obs}
"""
df = client.query(query)
df[:5]
# Out:
# <Table length=5>
# band exp_time    visit_id   ... aos_fwhm donut_blur_fwhm physical_rotator_angle
# str1 float64      int64     ...  object       object             object
# ---- -------- ------------- ... -------- --------------- ----------------------
#    r     30.0 2025072800004 ...     None            None                   None
#    r     30.0 2025072800005 ...     None            None                   None
#    r     30.0 2025072800006 ...     None            None                   None
#    r     30.0 2025072800007 ...     None            None                   None
#    r     30.0 2025072800008 ...     None            None                   None

# %% [markdown]
# ## Resources on EFD
#
# * [EFD documentation](https://sasquatch.lsst.io/user-guide/observatorytelemetry.html)
# * [Query examples](https://github.com/lsst-sqre/system-test/tree/main/efd_examples)
# * [Documentation for the python connection client](https://efd-client.lsst.io/api.html)

# %%
butler = dafButler.Butler('/repo/embargo_new', 
                          collections=["LSSTCam/raw/all", 
                                       "LSSTCam/calib", 
                                       # "LSSTCam/nightlyValidation"
                                                           ]
                         )
client = makeEfdClient()

# %% [markdown]
# Given eg. RubinTV, we can find two defocal pairs to query EFD for the time corresponding to just before the first exposure, and just after the last exposure. For instance, on  `20241030` seq_num `72` and `73`. One way to get the time spans is to query the registry, and look at `min`, `max` values of `dataId.exposure.timespan`

# %%
dataRefs = list(butler.registry.queryDatasets('postISRCCD', where="instrument='LSSTCam' and \
exposure.observation_type='acq' and day_obs = 20250728 and exposure.seq_num in (72,73)").expanded())

# %% [markdown]
# Or we can use the `butlerUtils` package to obtain the exposure record (including timespan) for the first and last seqNum:

# %%
expId = 2025072800099
dataId = {'exposure': expId, 'detector': 97, 'instrument': 'LSSTCam'}
expRecordBegin = butlerUtils.getExpRecordFromDataId(butler, dataId)

# %%
expId = 2025072800159
dataId = {'exposure': expId, 'detector': 97, 'instrument': 'LSSTCam'}
expRecordEnd = butlerUtils.getExpRecordFromDataId(butler, dataId)

# %%
expRecordBegin.timespan.begin
# Out:
# <Time object: scale='tai' format='jd' value=2460885.602868922>

# %%
expRecordEnd.timespan.end
# Out:
# <Time object: scale='tai' format='jd' value=2460885.6409620717>

# %%
td = expRecordEnd.timespan.end-expRecordBegin.timespan.begin
print('Time it took to take the ToO exposures:', td.sec, ' sec')
# Out:
# Time it took to take the ToO exposures: 3291.2481344679995  sec

# %% [markdown]
# ### Displaying EFD topics
# A list of EFD topics is available

# %%
topics = await client.get_topics()
len(topics)
# Out:
# 3095

# %% [markdown]
# A huge number of topics is available, to filter, let's select those with `lsst.sal`:

# %%
# from https://rubin-obs.slack.com/files/U07D8TLA3C3/F07QJPNTUE7/searching_the_efd
tt = [t.split('.') for t in topics]
topic_dict = {}
for t in tt:
    i = 0
    dd = topic_dict
    while i < len(t):
        if t[i] not in dd.keys():
            dd[t[i]] = {}
        dd = dd[t[i]]
        i += 1

# useful topics are 'lsst.sal.X' 
print(list(topic_dict['lsst']['sal'].keys()))
# Out:
# ['ATAOS', 'ATArchiver', 'ATBuilding', 'ATCamera', 'ATDome', 'ATDomeTrajectory', 'ATHeaderService', 'ATHexapod', 'ATMCS', 'ATMonochromator', 'ATOODS', 'ATPneumatics', 'ATPtg', 'ATSpectrograph', 'ATWhiteLight', 'AdamSensors', 'CBP', 'CCArchiver', 'CCCamera', 'CCHeaderService', 'CCOODS', 'DIMM', 'DREAM', 'DSM', 'Dome', 'EAS', 'EPM', 'ESS', 'Electrometer', 'Environment', 'FiberSpectrograph', 'GCHeaderService', 'GIS', 'GenericCamera', 'HVAC', 'Hexapod', 'LEDProjector', 'LaserTracker', 'LinearStage', 'MTAOS', 'MTAirCompressor', 'MTCamera', 'MTDome', 'MTDomeTrajectory', 'MTHeaderService', 'MTHexapod', 'MTM1M3', 'MTM1M3TS', 'MTM2', 'MTMount', 'MTOODS', 'MTPtg', 'MTReflector', 'MTRotator', 'MTVMS', 'NewMTMount', 'OCPS', 'PMD', 'Rotator', 'Scheduler', 'Script', 'ScriptQueue', 'Test', 'TunableLaser', 'Watcher', 'WeatherForecast', 'WeatherStation']

# %%
# Pick a CSC and see more about its topics
ss = 'MTCamera'
for tt in topic_dict['lsst']['sal'][ss].keys():
    topic = f'lsst.sal.{ss}.{tt}'
    print(topic)
    try:
        fields = await client.get_fields(topic)
    except: 
        fields  = ['value']
    fields = [f for f in fields if ('private' not in f) and (f != 'name') and (f != 'duration')]
    try:
        dd = await client.select_top_n(topic, fields, 1)
    except: 
        print('query failed')
    display(dd)
# Out:
# lsst.sal.MTCamera.ackcmd
#                                   ack  cmdtype  error       identity  origin  \
# 2025-08-19 01:18:54.258841+00:00  303       22      0  Script:300056   23024
#
#                                  result  timeout
# 2025-08-19 01:18:54.258841+00:00   Done        0
# lsst.sal.MTCamera.chiller_Chiller
#                                   cascadeSetPoint  chillerPumpLife  \
# 2024-12-11 17:31:16.716539+00:00             12.6              200
#
#                                   chillerValveAct  compressorLife  \
# 2024-12-11 17:31:16.716539+00:00            54666             202
#
#                                   controllerLife  coolPercentage  flowRate  \
# 2024-12-11 17:31:16.716539+00:00             637               0         0
#
#                                   flowSetPoint  fluidTemperature  \
# 2024-12-11 17:31:16.716539+00:00           0.5              12.6
#
#                                   heatPercentage  ...  pressureIn  \
# 2024-12-11 17:31:16.716539+00:00               0  ...           5
#
#                                   pressureOut  pressureTank  tankLevel  \
# 2024-12-11 17:31:16.716539+00:00          0.5             0          0
#
#                                   tankSetPoint  tempCondenser  \
# 2024-12-11 17:31:16.716539+00:00             0           8.11
#
#                                   tempDynamicSetPt  tempSetPoint  \
# 2024-12-11 17:31:16.716539+00:00                20            20
#
#                                   tempStage2Evap  tempTXVBulb
# 2024-12-11 17:31:16.716539+00:00            8.43         8.31
#
# [1 rows x 21 columns]
# lsst.sal.MTCamera.chiller_FParam_Trending
#                                   bubblev_TIME  clr_KI_SETPT  cold_PERIOD  \
# 2024-12-11 17:28:48.344992+00:00             1             0           10
#
#                                   cool_CAPACITY  dut_DT_HI  dut_DT_LO  dut_KI  \
# 2024-12-11 17:28:48.344992+00:00            100         50         50     0.3
#
#                                   dut_KP  dut_TMAX  dut_TMIN  ...  pid_KI  \
# 2024-12-11 17:28:48.344992+00:00     0.5        30       -70  ...     425
#
#                                   pid_KP  purge_TIME  ramp_DEFAULT  \
# 2024-12-11 17:28:48.344992+00:00       5           2           0.4
#
#                                   refrig_OFF  setpt_SETTLE  setpt_TOL  \
# 2024-12-11 17:28:48.344992+00:00           0            15          2
#
#                                   t_CTRL_MODE  tank_SETPOINT  thermsl_MASS
# 2024-12-11 17:28:48.344992+00:00            0              0           125
#
# [1 rows x 26 columns]
# lsst.sal.MTCamera.chiller_Maq20
#                                  ambientTemp coldPlHeatXfer coolantHXOut  \
# 2024-11-22 16:45:40.485231+00:00        None           None         None
#
#                                  coolantHeatXfer coolantPumpIn coolantPumpOut  \
# 2024-11-22 16:45:40.485231+00:00            None          None           None
#
#                                  coolantReturn coolantSupply fan1Speed  \
# 2024-11-22 16:45:40.485231+00:00          None          None      None
#
#                                  fan2Speed  ... stg1CondensOut stg1Discharge  \
# 2024-11-22 16:45:40.485231+00:00      None  ...           None          None
#
#                                  stg1Return stg1TXVBulb stg2DeSuHtrOut  \
# 2024-11-22 16:45:40.485231+00:00       None        None           None
#
#                                  stg2Discharge stg2DischargeP stg2EvapIn  \
# 2024-11-22 16:45:40.485231+00:00          None           None       None
#
#                                   stg2EvapOut  stg2Return
# 2024-11-22 16:45:40.485231+00:00         None        None
#
# [1 rows x 30 columns]
# lsst.sal.MTCamera.command_disable
# query failed
#                                  ambientTemp coldPlHeatXfer coolantHXOut  \
# 2024-11-22 16:45:40.485231+00:00        None           None         None
#
#                                  coolantHeatXfer coolantPumpIn coolantPumpOut  \
# 2024-11-22 16:45:40.485231+00:00            None          None           None
#
#                                  coolantReturn coolantSupply fan1Speed  \
# 2024-11-22 16:45:40.485231+00:00          None          None      None
#
#                                  fan2Speed  ... stg1CondensOut stg1Discharge  \
# 2024-11-22 16:45:40.485231+00:00      None  ...           None          None
#
#                                  stg1Return stg1TXVBulb stg2DeSuHtrOut  \
# 2024-11-22 16:45:40.485231+00:00       None        None           None
#
#                                  stg2Discharge stg2DischargeP stg2EvapIn  \
# 2024-11-22 16:45:40.485231+00:00          None           None       None
#
#                                   stg2EvapOut  stg2Return
# 2024-11-22 16:45:40.485231+00:00         None        None
#
# [1 rows x 30 columns]
# lsst.sal.MTCamera.command_disableCalibration
# query failed
#                                  ambientTemp coldPlHeatXfer coolantHXOut  \
# 2024-11-22 16:45:40.485231+00:00        None           None         None
#
#                                  coolantHeatXfer coolantPumpIn coolantPumpOut  \
# 2024-11-22 16:45:40.485231+00:00            None          None           None
#
#                                  coolantReturn coolantSupply fan1Speed  \
# 2024-11-22 16:45:40.485231+00:00          None          None      None
#
#                                  fan2Speed  ... stg1CondensOut stg1Discharge  \
# 2024-11-22 16:45:40.485231+00:00      None  ...           None          None
#
#                                  stg1Return stg1TXVBulb stg2DeSuHtrOut  \
# 2024-11-22 16:45:40.485231+00:00       None        None           None
#
#                                  stg2Discharge stg2DischargeP stg2EvapIn  \
# 2024-11-22 16:45:40.485231+00:00          None           None       None
#
#                                   stg2EvapOut  stg2Return
# 2024-11-22 16:45:40.485231+00:00         None        None
#
# [1 rows x 30 columns]
# lsst.sal.MTCamera.command_discardRows
#                                   nRows
# 2025-04-16 23:52:19.929411+00:00   2000
# lsst.sal.MTCamera.command_enable
# query failed
#                                   nRows
# 2025-04-16 23:52:19.929411+00:00   2000
# lsst.sal.MTCamera.command_enableCalibration
# query failed
#                                   nRows
# 2025-04-16 23:52:19.929411+00:00   2000
# lsst.sal.MTCamera.command_endImage
# query failed
#                                   nRows
# 2025-04-16 23:52:19.929411+00:00   2000
# lsst.sal.MTCamera.command_enterControl
# query failed
#                                   nRows
# 2025-04-16 23:52:19.929411+00:00   2000
# lsst.sal.MTCamera.command_exitControl
# query failed
#                                   nRows
# 2025-04-16 23:52:19.929411+00:00   2000
# lsst.sal.MTCamera.command_initGuiders
#                                                                             roiSpec
# 2025-08-19 01:18:45.054462+00:00  {"common":{"rows":400,"cols":400,"integrationT...
# lsst.sal.MTCamera.command_setFilter
# query failed
#                                                                             roiSpec
# 2025-08-19 01:18:45.054462+00:00  {"common":{"rows":400,"cols":400,"integrationT...
# lsst.sal.MTCamera.command_standby
# query failed
#                                                                             roiSpec
# 2025-08-19 01:18:45.054462+00:00  {"common":{"rows":400,"cols":400,"integrationT...
# lsst.sal.MTCamera.command_start
#                                  configurationOverride
# 2025-08-17 15:04:12.389896+00:00
# lsst.sal.MTCamera.command_startImage
#                                                                         keyValueMap  \
# 2025-04-16 23:52:17.813356+00:00  imageType: STUTTERED, groupId: 2025-04-16T23:5...
#
#                                  obsNote sensors  shutter  timeout
# 2025-04-16 23:52:17.813356+00:00                     True       11
# lsst.sal.MTCamera.command_takeImages
#                                   expTime  \
# 2025-08-19 01:18:48.221580+00:00        5
#
#                                                                         keyValueMap  \
# 2025-08-19 01:18:48.221580+00:00  imageType: FLAT, groupId: 2025-08-19T01:03:56....
#
#                                   numImages obsNote sensors  shutter
# 2025-08-19 01:18:48.221580+00:00          1                     True
# lsst.sal.MTCamera.daq_monitor_Reb_Trending
# query failed
#                                   expTime  \
# 2025-08-19 01:18:48.221580+00:00        5
#
#                                                                         keyValueMap  \
# 2025-08-19 01:18:48.221580+00:00  imageType: FLAT, groupId: 2025-08-19T01:03:56....
#
#                                   numImages obsNote sensors  shutter
# 2025-08-19 01:18:48.221580+00:00          1                     True
# lsst.sal.MTCamera.daq_monitor_Store
#                                        capacity  freeFraction     freeSpace
# 2025-08-19 16:04:24.891933+00:00  165006.737702      0.233884  38592.513104
# lsst.sal.MTCamera.daq_monitor_Sum_Trending
#                                   driver_errors  firmware_cell_errors  \
# 2025-08-19 16:04:19.164819+00:00              0                     0
#
#                                   firmware_link_down  firmware_link_errors  \
# 2025-08-19 16:04:19.164819+00:00                  67                     5
#
#                                   firmware_overflow_local0  \
# 2025-08-19 16:04:19.164819+00:00                         0
#
#                                   firmware_overflow_local1  \
# 2025-08-19 16:04:19.164819+00:00                         0
#
#                                   firmware_overflow_local2  \
# 2025-08-19 16:04:19.164819+00:00                         0
#
#                                   firmware_overflow_remote0  \
# 2025-08-19 16:04:19.164819+00:00                          0
#
#                                   firmware_overflow_remote1  \
# 2025-08-19 16:04:19.164819+00:00                          1
#
#                                   firmware_overflow_remote2  ...  \
# 2025-08-19 16:04:19.164819+00:00                          0  ...
#
#                                   rds_bdi_nulls  rds_bdi_overflows  \
# 2025-08-19 16:04:19.164819+00:00              0                  0
#
#                                   rds_bdi_seq_errors  rds_discards  \
# 2025-08-19 16:04:19.164819+00:00                   0             0
#
#                                   rds_no_event  rms_in_reset  rms_inv_tids  \
# 2025-08-19 16:04:19.164819+00:00             0             0             0
#
#                                   rms_link_down  rms_orphans  rms_unopened
# 2025-08-19 16:04:19.164819+00:00              0            0             0
#
# [1 rows x 22 columns]
# lsst.sal.MTCamera.focal_plane_Ccd
#                                        gDV0       gDV1 gDV10 gDV100 gDV101  \
# 2025-08-19 16:04:44.940085+00:00  19.988647  19.982217  None   None   None
#
#                                  gDV102 gDV103 gDV104     gDV105     gDV106  \
# 2025-08-19 16:04:44.940085+00:00   None   None   None  26.002442  26.002442
#
#                                   ...     temp90     temp91     temp92 temp93  \
# 2025-08-19 16:04:44.940085+00:00  ... -96.558843 -96.768776 -96.562559   None
#
#                                   temp94 temp95 temp96 temp97 temp98  \
# 2025-08-19 16:04:44.940085+00:00    None   None   None   None   None
#
#                                      temp99
# 2025-08-19 16:04:44.940085+00:00 -92.937977
#
# [1 rows x 1207 columns]
# lsst.sal.MTCamera.focal_plane_Reb
#                                  anaI0 anaI1 anaI10  anaI11 anaI12  anaI13  \
# 2025-08-19 16:05:55.109998+00:00  None  None   None  615.75   None  573.75
#
#                                  anaI14  anaI15 anaI16 anaI17  ... temp964  \
# 2025-08-19 16:05:55.109998+00:00   None   571.0   None   None  ...  2.8125
#
#                                  temp965  temp966 temp967  temp968  temp969  \
# 2025-08-19 16:05:55.109998+00:00 -1.8125     None -1.1875     None     None
#
#                                   temp97  temp970 temp98 temp99
# 2025-08-19 16:05:55.109998+00:00    None        0   None   None
#
# [1 rows x 3622 columns]
# lsst.sal.MTCamera.focal_plane_RebTotalPower
#                                   rebTotalPower
# 2025-08-19 16:05:55.119605+00:00    1006.697664
# lsst.sal.MTCamera.focal_plane_RebsAverageTemp6
#                                   rebsAverageTemp6
# 2025-08-19 16:06:05.179761+00:00           -4.0625
# lsst.sal.MTCamera.focal_plane_Segment
#                                     i0    i1   i10  i100 i1000 i1001 i1002  \
# 2025-08-19 16:06:55.247617+00:00  None  None  None  None  None  None  None
#
#                                  i1003 i1004 i1005  ...  i991  i992  i993  \
# 2025-08-19 16:06:55.247617+00:00  None  None  None  ...  None  None  None
#
#                                   i994  i995  i996  i997  i998  i999  \
# 2025-08-19 16:06:55.247617+00:00  None  None  None  None  None  None
#
#                                                                            location
# 2025-08-19 16:06:55.247617+00:00  R01S00Seg00:R01S00Seg01:R01S00Seg02:R01S00Seg0...
#
# [1 rows x 3025 columns]
# lsst.sal.MTCamera.hex_Cold1
#                                   returnTmp  supplyTmp
# 2025-08-19 16:06:57.879972+00:00 -43.874502  -48.75498
# lsst.sal.MTCamera.hex_Cold2
#                                   returnTmp  supplyTmp
# 2025-08-19 16:06:57.891248+00:00 -44.422311  -48.75498
# lsst.sal.MTCamera.hex_Cryo1
#                                   c3ExitTmp   c4ExitTmp  evapExitTmp  \
# 2025-08-19 16:07:07.916619+00:00 -69.521912 -145.567729   -129.98008
#
#                                   hexRtrnTmp   liquidPrs   preC3Tmp  \
# 2025-08-19 16:07:07.916619+00:00    0.448207  373.146063 -27.041833
#
#                                     preC4Tmp  returnPrs    vaporPrs
# 2025-08-19 16:07:07.916619+00:00 -123.256972  18.408661  380.443701
# lsst.sal.MTCamera.hex_Cryo2
#                                   c3ExitTmp   c4ExitTmp  evapExitTmp  \
# 2025-08-19 16:07:07.928841+00:00 -20.468127 -141.832669  -135.756972
#
#                                   hexRtrnTmp   liquidPrs   preC3Tmp  \
# 2025-08-19 16:07:07.928841+00:00    4.432271  381.274016 -14.243028
#
#                                     preC4Tmp  returnPrs    vaporPrs
# 2025-08-19 16:07:07.928841+00:00 -122.211155  23.222047  390.624409
# lsst.sal.MTCamera.hex_Cryo3
#                                   c3ExitTmp   c4ExitTmp  evapExitTmp  \
# 2025-08-19 16:07:07.940638+00:00 -67.928287 -139.641434   -130.02988
#
#                                   hexRtrnTmp  liquidPrs  preC3Tmp    preC4Tmp  \
# 2025-08-19 16:07:07.940638+00:00   -3.884462  352.09252 -8.615538 -121.115538
#
#                                   returnPrs    vaporPrs
# 2025-08-19 16:07:07.940638+00:00  22.809711  363.911417
# lsst.sal.MTCamera.hex_Cryo4
#                                   c3ExitTmp   c4ExitTmp  evapExitTmp  \
# 2025-08-19 16:07:17.949271+00:00 -69.322709 -137.400398  -131.324701
#
#                                   hexRtrnTmp   liquidPrs   preC3Tmp  \
# 2025-08-19 16:07:17.949271+00:00    1.394422  353.330709 -13.247012
#
#                                     preC4Tmp  returnPrs    vaporPrs
# 2025-08-19 16:07:17.949271+00:00 -124.800797  34.308399  361.150787
# lsst.sal.MTCamera.hex_Cryo5
#                                   c3ExitTmp   c4ExitTmp  evapExitTmp  \
# 2025-08-19 16:07:17.962519+00:00  -54.98008 -136.005976  -127.739044
#
#                                   hexRtrnTmp   liquidPrs   preC3Tmp  \
# 2025-08-19 16:07:17.962519+00:00    4.033865  362.181102 -15.139442
#
#                                     preC4Tmp  returnPrs    vaporPrs
# 2025-08-19 16:07:17.962519+00:00 -120.816733  27.723097  373.023622
# lsst.sal.MTCamera.hex_Cryo6
#                                   c3ExitTmp   c4ExitTmp  evapExitTmp  \
# 2025-08-19 16:07:27.969268+00:00 -68.276892 -134.213147  -130.378486
#
#                                   hexRtrnTmp  liquidPrs  preC3Tmp    preC4Tmp  \
# 2025-08-19 16:07:27.969268+00:00    0.498008  354.35315 -9.213147 -123.256972
#
#                                   returnPrs    vaporPrs
# 2025-08-19 16:07:27.969268+00:00  23.322047  364.187795
# lsst.sal.MTCamera.logevent_availableFilters
#                                               filterNames   filterTypes  \
# 2025-08-17 15:04:12.744145+00:00  NONE,g_6,z_20,i_39,r_57  none,g,z,i,r
#
#                                   maxChangeAngle  maxFastChangeAngle  \
# 2025-08-17 15:04:12.744145+00:00              90           70.528779
#
#                                   maxFastChangeTime0  maxFastChangeTime1  \
# 2025-08-17 15:04:12.744145+00:00                  95                  95
#
#                                   maxFastChangeTime2  maxFastChangeTime3  \
# 2025-08-17 15:04:12.744145+00:00                  95                  95
#
#                                   maxFastChangeTime4 maxFastChangeTime5  \
# 2025-08-17 15:04:12.744145+00:00                  95               None
#
#                                   maxSlowChangeTime0  maxSlowChangeTime1  \
# 2025-08-17 15:04:12.744145+00:00                 120                 120
#
#                                   maxSlowChangeTime2  maxSlowChangeTime3  \
# 2025-08-17 15:04:12.744145+00:00                 120                 120
#
#                                   maxSlowChangeTime4 maxSlowChangeTime5
# 2025-08-17 15:04:12.744145+00:00                 120               None
# lsst.sal.MTCamera.logevent_calibrationDetailedState
#                                   substate  timestampTransition
# 2025-08-15 20:16:53.096811+00:00         1         1.755289e+09
# lsst.sal.MTCamera.logevent_ccsCommandState
#                                   substate  timestampTransition
# 2025-08-19 01:18:54.273165+00:00         1         1.755566e+09
# lsst.sal.MTCamera.logevent_chiller_DeviceConfiguration
#                                      maq20_node  \
# 2024-12-11 17:28:47.879191+00:00  192.168.1.158
#
#                                                                       maq20_serials  \
# 2024-12-11 17:28:47.879191+00:00  0141086-08:0131744-09:0152808-08:0140366-07:01...
#
#                                      pluto_node  \
# 2024-12-11 17:28:47.879191+00:00  192.168.1.160
#
#                                                              version
# 2024-12-11 17:28:47.879191+00:00  Device:Chiller/defaultInitial(d=7)
# lsst.sal.MTCamera.logevent_chiller_DevicesConfiguration
#                                   chiller_disabled  maq20_disabled  \
# 2024-12-11 17:28:47.880359+00:00             False           False
#
#                                   pluto_disabled  \
# 2024-12-11 17:28:47.880359+00:00           False
#
#                                                               version
# 2024-12-11 17:28:47.880359+00:00  Devices:Chiller/defaultInitial(d=2)
# lsst.sal.MTCamera.logevent_chiller_GeneralConfiguration
#                                  chiller_host  \
# 2024-12-11 17:28:47.881558+00:00  192.168.1.2
#
#                                  chilleralertlistener_thermalAlertSource  \
# 2024-12-11 17:28:47.881558+00:00                                 thermal
#
#                                  chilleralertlistener_vacuumAlertSource  \
# 2024-12-11 17:28:47.881558+00:00                                 vacuum
#
#                                  coldInletChannelPath coldOutletChannelPath  \
# 2024-12-11 17:28:47.881558+00:00             NOTFOUND              NOTFOUND
#
#                                  coldplateChannelPath  connectedToCamera  \
# 2024-12-11 17:28:47.881558+00:00             NOTFOUND              False
#
#                                   glycolCooling  listenTo  \
# 2024-12-11 17:28:47.881558+00:00          False  NOTFOUND
#
#                                  maq20_ColdPlHeatXfer_flowChanPath  ...  \
# 2024-12-11 17:28:47.881558+00:00                  Chiller/FlowRate  ...
#
#                                  maq20_GlycHeatXfer_flowChanPath  \
# 2024-12-11 17:28:47.881558+00:00             Maq20/GlycInputFlow
#
#                                  maq20_GlycHeatXfer_inletTChanPath  \
# 2024-12-11 17:28:47.881558+00:00               Maq20/GlycChillerIn
#
#                                  maq20_GlycHeatXfer_outletTChanPath  \
# 2024-12-11 17:28:47.881558+00:00               Maq20/GlycChillerOut
#
#                                  periodictasks_schedulers_default_nTasks  \
# 2024-12-11 17:28:47.881558+00:00                                      11
#
#                                  periodictasks_schedulers_default_nThreads  \
# 2024-12-11 17:28:47.881558+00:00                                         8
#
#                                  periodictasks_schedulers_monitor_check_scheduler_nTasks  \
# 2024-12-11 17:28:47.881558+00:00                                                  3
#
#                                  periodictasks_schedulers_monitor_check_scheduler_nThreads  \
# 2024-12-11 17:28:47.881558+00:00                                                  2
#
#                                  periodictasks_schedulers_monitor_update_publish_scheduler_nTasks  \
# 2024-12-11 17:28:47.881558+00:00                                                  4
#
#                                   periodictasks_schedulers_monitor_update_publish_scheduler_nThreads  \
# 2024-12-11 17:28:47.881558+00:00                                                  2
#
#                                                               version
# 2024-12-11 17:28:47.881558+00:00  General:Chiller/defaultInitial(d=8)
#
# [1 rows x 25 columns]
# lsst.sal.MTCamera.logevent_chiller_LimitsConfiguration
#                                   chiller_TempDUTInput_limitHi  \
# 2024-12-11 17:28:47.882532+00:00                           600
#
#                                   chiller_TempDUTInput_warnHi  \
# 2024-12-11 17:28:47.882532+00:00                          150
#
#                                   maq20_PBurstReturn_limitHi  \
# 2024-12-11 17:28:47.882532+00:00                         4.5
#
#                                   maq20_PBurstReturn_warnHi  \
# 2024-12-11 17:28:47.882532+00:00                        1.5
#
#                                   maq20_PBurstSupply_limitHi  \
# 2024-12-11 17:28:47.882532+00:00                         4.5
#
#                                   maq20_PBurstSupply_warnHi  \
# 2024-12-11 17:28:47.882532+00:00                        1.5
#
#                                                               version
# 2024-12-11 17:28:47.882532+00:00  Limits:Chiller/defaultInitial(d=13)
# lsst.sal.MTCamera.logevent_chiller_PicConfiguration
#                                   fanctrl_awGain  fanctrl_baseDuty  \
# 2024-12-11 17:28:47.883416+00:00               4                 0
#
#                                   fanctrl_gain  fanctrl_maxInput  \
# 2024-12-11 17:28:47.883416+00:00           0.3                50
#
#                                   fanctrl_maxOutput  fanctrl_minInput  \
# 2024-12-11 17:28:47.883416+00:00                  1               -50
#
#                                   fanctrl_minOutput  fanctrl_setTemp  \
# 2024-12-11 17:28:47.883416+00:00                  0                1
#
#                                   fanctrl_smoothTime  fanctrl_timeConst  \
# 2024-12-11 17:28:47.883416+00:00                  60                120
#
#                                   fanctrl_tolerance  fanctrl_useAbsTemp  \
# 2024-12-11 17:28:47.883416+00:00               0.05               False
#
#                                   periodictasks_FanCtrl_iterate_updateTime  \
# 2024-12-11 17:28:47.883416+00:00                                     10000
#
#                                                           version
# 2024-12-11 17:28:47.883416+00:00  Pic:Chiller/defaultInitial(d=1)
# lsst.sal.MTCamera.logevent_chiller_timersConfiguration
#                                   periodictasks_Maq20_check_status_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                              10000
#
#                                   periodictasks_agentMonitorService_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                              60000
#
#                                   periodictasks_checkBurstDiscP_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                             500
#
#                                   periodictasks_checkDataArrival_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                              500
#
#                                   periodictasks_heartbeat_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                      1000
#
#                                   periodictasks_monitor_check_Chiller_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                              10000
#
#                                   periodictasks_monitor_check_Maq20_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                              10000
#
#                                   periodictasks_monitor_check_Pluto_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                              10000
#
#                                   periodictasks_monitor_publish_burstDiscs_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                               2000
#
#                                   periodictasks_monitor_publish_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                           10000
#
#                                   periodictasks_monitor_update_burstDiscs_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                                500
#
#                                   periodictasks_monitor_update_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                           2000
#
#                                   periodictasks_publishParams_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                       1800000
#
#                                   periodictasks_runtimeInfo_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                       60000
#
#                                   periodictasks_sendDutTemperature_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                               1000
#
#                                   periodictasks_updateCtrlState_taskPeriodMillis  \
# 2024-12-11 17:28:47.884500+00:00                                            1000
#
#                                                              version
# 2024-12-11 17:28:47.884500+00:00  timers:Chiller/defaultInitial(d=6)
# lsst.sal.MTCamera.logevent_configurationApplied
#                                  configurations  \
# 2025-08-17 15:04:13.445487+00:00         Normal
#
#                                                                           otherInfo  \
# 2025-08-17 15:04:13.445487+00:00  utiltrunk_UtMaq20_DevicesConfiguration,focal_p...
#
#                                  schemaVersion  \
# 2025-08-17 15:04:13.445487+00:00       UNKNOWN
#
#                                                                                 url  \
# 2025-08-17 15:04:13.445487+00:00  https://lsst-camera-dev.slac.stanford.edu/Rest...
#
#                                  version
# 2025-08-17 15:04:13.445487+00:00   1.0.0
# lsst.sal.MTCamera.logevent_configurationsAvailable
#                                  overrides schemaVersion  \
# 2025-08-17 15:04:12.318120+00:00    Normal       UNKNOWN
#
#                                                                                 url  \
# 2025-08-17 15:04:12.318120+00:00  https://lsst-camera-dev.slac.stanford.edu/Rest...
#
#                                  version
# 2025-08-17 15:04:12.318120+00:00   1.0.0
# lsst.sal.MTCamera.logevent_daq_monitor_PeriodicTasks_GeneralConfiguration
#                                   schedulers_default_nTasks  \
# 2025-08-18 20:38:14.196374+00:00                          7
#
#                                   schedulers_default_nThreads  \
# 2025-08-18 20:38:14.196374+00:00                            8
#
#                                   schedulers_monitor_update_publish_scheduler_nTasks  \
# 2025-08-18 20:38:14.196374+00:00                                                  2
#
#                                   schedulers_monitor_update_publish_scheduler_nThreads  \
# 2025-08-18 20:38:14.196374+00:00                                                  2
#
#                                                                  version
# 2025-08-18 20:38:14.196374+00:00  General:DaqMonitor/defaultInitial(d=1)
# lsst.sal.MTCamera.logevent_daq_monitor_PeriodicTasks_timersConfiguration
#                                   agentmonitorservice_taskPeriodMillis  \
# 2025-08-18 20:38:14.253633+00:00                                 60000
#
#                                   heartbeat_taskPeriodMillis  \
# 2025-08-18 20:38:14.253633+00:00                        1000
#
#                                   monitor_check_taskPeriodMillis  \
# 2025-08-18 20:38:14.253633+00:00                           10000
#
#                                   monitor_publish_taskPeriodMillis  \
# 2025-08-18 20:38:14.253633+00:00                             10000
#
#                                   monitor_update_taskPeriodMillis  \
# 2025-08-18 20:38:14.253633+00:00                             1000
#
#                                   publishstats_taskPeriodMillis  \
# 2025-08-18 20:38:14.253633+00:00                          15000
#
#                                   purgedaq_taskPeriodMillis  \
# 2025-08-18 20:38:14.253633+00:00                     900000
#
#                                   runtimeinfo_taskPeriodMillis  \
# 2025-08-18 20:38:14.253633+00:00                         60000
#
#                                                                 version
# 2025-08-18 20:38:14.253633+00:00  timers:DaqMonitor/defaultInitial(d=5)
# lsst.sal.MTCamera.logevent_daq_monitor_Stats_StatisticsConfiguration
#                                   minDiffAlertWarning  minDiffLogWarning  \
# 2025-08-18 20:38:14.322215+00:00                    2                  1
#
#                                  sumDriverChecks sumDriverStats  \
# 2025-08-18 20:38:14.322215+00:00        [errors]       [errors]
#
#                                                                   sumFirmwareChecks  \
# 2025-08-18 20:38:14.322215+00:00  [cell_errors, link_down, link_errors, overflow...
#
#                                                                    sumFirmwareStats  \
# 2025-08-18 20:38:14.322215+00:00  [cell_errors, link_down, link_errors, overflow...
#
#                                                                        sumRdsChecks  \
# 2025-08-18 20:38:14.322215+00:00  [discards, bdi_nulls, bdi_seq_errors, bdi_over...
#
#                                                                         sumRdsStats  \
# 2025-08-18 20:38:14.322215+00:00  [discards, no_event, bdi_nulls, bdi_seq_errors...
#
#                                                              sumRmsChecks  \
# 2025-08-18 20:38:14.322215+00:00  [unopened, in_reset, inv_tids, orphans]
#
#                                                                         sumRmsStats  \
# 2025-08-18 20:38:14.322215+00:00  [unopened, in_reset, link_down, inv_tids, orph...
#
#                                                                     version
# 2025-08-18 20:38:14.322215+00:00  Statistics:DaqMonitor/defaultInitial(d=5)
# lsst.sal.MTCamera.logevent_daq_monitor_StoreConfiguration
#                                   alarmPurgeFailures daqPartition  \
# 2025-08-18 20:38:14.410129+00:00          -111111111     NOTFOUND
#
#                                                                             version
# 2025-08-18 20:38:14.410129+00:00  Store:DaqMonitor/common(d=5)|DaqMonitor/camera...
# lsst.sal.MTCamera.logevent_daq_monitor_Store_DevicesConfiguration
#                                   disabled  \
# 2025-08-18 20:38:14.470987+00:00     False
#
#                                                                  version
# 2025-08-18 20:38:14.470987+00:00  Devices:DaqMonitor/defaultInitial(d=5)
# lsst.sal.MTCamera.logevent_daq_monitor_Store_LimitsConfiguration
#                                   freefraction_limitLo  freefraction_warnLo  \
# 2025-08-18 20:38:14.499837+00:00                  0.05                  0.2
#
#                                                                  version
# 2025-08-18 20:38:14.499837+00:00  Limits:DaqMonitor/defaultInitial(d=11)
# lsst.sal.MTCamera.logevent_daq_monitor_Store_StoreConfiguration
#                                  daqFolder  enableAutoPurge  purgeTarget  \
# 2025-08-18 20:38:14.542080+00:00       raw             True          0.7
#
#                                   purgeThreshold  \
# 2025-08-18 20:38:14.542080+00:00             0.8
#
#                                                                             version
# 2025-08-18 20:38:14.542080+00:00  Store:DaqMonitor/common(d=5)|DaqMonitor/camera...
# lsst.sal.MTCamera.logevent_endLoadFilter
#                                   timestampTransition
# 2025-08-18 04:21:59.771285+00:00         1.755491e+09
# lsst.sal.MTCamera.logevent_endOfImageTelemetry
#                                                                      additionalKeys  \
# 2025-08-19 01:18:57.803404+00:00  imageType:groupId:testType:stutterRows:stutter...
#
#                                                                    additionalValues  \
# 2025-08-19 01:18:57.803404+00:00  FLAT:2025-08-19T01\:03\:56.744:FLAT:0:0:0.0:jg...
#
#                                   darkTime emulatedImage  exposureTime  \
# 2025-08-19 01:18:57.803404+00:00  5.926673                           5
#
#                                  imageController imageDate  imageIndex  \
# 2025-08-19 01:18:57.803404+00:00               O  20250818           1
#
#                                              imageName  imageNumber  \
# 2025-08-19 01:18:57.803404+00:00  MC_O_20250818_000269          269
#
#                                  imageSource          imageTag  \
# 2025-08-19 01:18:57.803404+00:00          MC  5d3038e6129634a5
#
#                                   imagesInSequence  measuredShutterOpenTime  \
# 2025-08-19 01:18:57.803404+00:00                 1                    5.001
#
#                                   timestampAcquisitionStart  timestampDateEnd  \
# 2025-08-19 01:18:57.803404+00:00               1.755566e+09      1.755566e+09
#
#                                   timestampDateObs
# 2025-08-19 01:18:57.803404+00:00      1.755566e+09
# lsst.sal.MTCamera.logevent_endReadout
#                                                                      additionalKeys  \
# 2025-08-19 01:18:57.503184+00:00  imageType:groupId:testType:stutterRows:stutter...
#
#                                                                    additionalValues  \
# 2025-08-19 01:18:57.503184+00:00  FLAT:2025-08-19T01\:03\:56.744:FLAT:0:0:0.0:jg...
#
#                                  imageController imageDate  imageIndex  \
# 2025-08-19 01:18:57.503184+00:00               O  20250818           1
#
#                                              imageName  imageNumber  \
# 2025-08-19 01:18:57.503184+00:00  MC_O_20250818_000269          269
#
#                                  imageSource  imagesInSequence  \
# 2025-08-19 01:18:57.503184+00:00          MC                 1
#
#                                   requestedExposureTime  \
# 2025-08-19 01:18:57.503184+00:00                      5
#
#                                   timestampAcquisitionStart  \
# 2025-08-19 01:18:57.503184+00:00               1.755566e+09
#
#                                   timestampEndOfReadout
# 2025-08-19 01:18:57.503184+00:00           1.755566e+09
# lsst.sal.MTCamera.logevent_endRotateCarousel
#                                   timestampTransition
# 2025-04-06 22:08:31.609596+00:00         1.743977e+09
# lsst.sal.MTCamera.logevent_endSetFilter
#                                  filterName  filterPosition  filterSlot  \
# 2025-08-18 20:38:13.713497+00:00       i_39             308           1
#
#                                  filterType
# 2025-08-18 20:38:13.713497+00:00          i
# lsst.sal.MTCamera.logevent_endShutterClose
#                                   timestampTransition
# 2025-08-19 01:18:54.236741+00:00         1.755566e+09
# lsst.sal.MTCamera.logevent_endShutterOpen
#                                   timestampTransition
# 2025-08-19 01:18:49.238744+00:00         1.755566e+09
# lsst.sal.MTCamera.logevent_endUnloadFilter
#                                   timestampTransition
# 2025-04-10 19:02:36.246522+00:00         1.744312e+09
# lsst.sal.MTCamera.logevent_errorCode
#                                   errorCode  \
# 2025-08-16 22:59:43.230630+00:00       1099
#
#                                                                         errorReport  \
# 2025-08-16 22:59:43.230630+00:00  MCM has entered fault state. Cause: Controlled...
#
#                                  traceback
# 2025-08-16 22:59:43.230630+00:00
# lsst.sal.MTCamera.logevent_fcs_PeriodicTasks_GeneralConfiguration
#    schedulers_default_nTasks  schedulers_default_nThreads  \
# 0                         47                         4064
#
#    schedulers_monitor_update_publish_scheduler_nTasks  \
# 0                                                  8
#
#    schedulers_monitor_update_publish_scheduler_nThreads  \
# 0                                            -520267
#
#                              version
# 0  ��?�^�?\t��?@��?@��?q��?q��?�-�?�
# lsst.sal.MTCamera.logevent_fcs_PeriodicTasks_timersConfiguration
#    agentmonitorservice_taskPeriodMillis  heartbeat_taskPeriodMillis  \
# 0                                 -2767                          24
#
#    main_checkControllers_taskPeriodMillis  main_updateGui_taskPeriodMillis  \
# 0                                    -972                               22
#
#    monitor_check_taskPeriodMillis  monitor_publish_taskPeriodMillis  \
# 0                            7935                              2832
#
#    monitor_update_taskPeriodMillis  runtimeinfo_taskPeriodMillis  \
# 0                            -2454                          2823
#
#                                     version
# 0  ,��!-
# q:(�w�+\t',i�+ۃk+��\n,0o�-b,��
# lsst.sal.MTCamera.logevent_fcs_Seneca1_DevicesConfiguration
#    disabled version
# 0     False
# lsst.sal.MTCamera.logevent_filterChangerDetailedState
#                                   substate  timestampTransition
# 2025-08-18 04:21:59.792463+00:00         3         1.755491e+09
# lsst.sal.MTCamera.logevent_focalPlaneSummaryInfo
#                                                                         ccdLSSTName  \
# 2025-08-18 20:38:13.767509+00:00  ITL-3800C-397:ITL-3800C-337:ITL-4400B-023:ITL-...
#
#                                                                         ccdLocation  \
# 2025-08-18 20:38:13.767509+00:00  R00SG0:R00SG1:R00SW0:R00SW1:R01S00:R01S01:R01S...
#
#                                                                        ccdManSerNum  \
# 2025-08-18 20:38:13.767509+00:00  24778:24378:21835:21834:22241:23000:22313:2071...
#
#                                                                     ccdManufacturer  \
# 2025-08-18 20:38:13.767509+00:00  ITL:ITL:ITL:ITL:ITL:ITL:ITL:ITL:ITL:ITL:ITL:IT...
#
#                                                                             ccdSlot  \
# 2025-08-18 20:38:13.767509+00:00  SG0:SG1:SW0:SW1:S00:S01:S02:S10:S11:S12:S20:S2...
#
#                                   ccdTempSetPoint0  ccdTempSetPoint1  \
# 2025-08-18 20:38:13.767509+00:00            -103.5            -103.5
#
#                                   ccdTempSetPoint10  ccdTempSetPoint100  \
# 2025-08-18 20:38:13.767509+00:00             -101.8              -101.8
#
#                                   ccdTempSetPoint101  ...  ccdType96  \
# 2025-08-18 20:38:13.767509+00:00              -101.8  ...          1
#
#                                   ccdType97  ccdType98  ccdType99  \
# 2025-08-18 20:38:13.767509+00:00          1          1          1
#
#                                                                             raftBay  \
# 2025-08-18 20:38:13.767509+00:00  R00:R00:R00:R00:R01:R01:R01:R01:R01:R01:R01:R0...
#
#                                                                        raftLSSTName  \
# 2025-08-18 20:38:13.767509+00:00  LCA-10692_CRTM-0002:LCA-10692_CRTM-0002:LCA-10...
#
#                                                                         rebLSSTName  \
# 2025-08-18 20:38:13.767509+00:00  LCA-13540-05:LCA-13540-05:LCA-13537-04:LCA-135...
#
#                                                                     rebSerialNumber  \
# 2025-08-18 20:38:13.767509+00:00  412160871:412160871:412164444:412164444:418223...
#
#                                                                   sequencerChecksum  \
# 2025-08-18 20:38:13.767509+00:00  415083004:415083004:415083004:415083004:415083...
#
#                                                                        sequencerKey
# 2025-08-18 20:38:13.767509+00:00  FP_ITL_3s_cp_v1.seq:FP_ITL_3s_cp_v1.seq:FP_ITL...
#
# [1 rows x 421 columns]
# lsst.sal.MTCamera.logevent_focal_plane_Ccd_HardwareIdConfiguration
#                                                                            location  \
# 2025-08-18 20:38:14.054007+00:00  R00SG0:R00SG1:R00SW0:R00SW1:R01S00:R01S01:R01S...
#
#                                                                           manSerNum  \
# 2025-08-18 20:38:14.054007+00:00  24778:24378:21835:21834:22241:23000:22313:2071...
#
#                                                             version
# 2025-08-18 20:38:14.054007+00:00  HardwareId:FocalPlane/camera(d=1)
# lsst.sal.MTCamera.logevent_focal_plane_Ccd_LimitsConfiguration
#                                   gdv_limitHi0  gdv_limitHi1  gdv_limitHi10  \
# 2025-08-18 20:38:14.114385+00:00            22            22           21.5
#
#                                   gdv_limitHi100  gdv_limitHi101  \
# 2025-08-18 20:38:14.114385+00:00              27              27
#
#                                   gdv_limitHi102  gdv_limitHi103  \
# 2025-08-18 20:38:14.114385+00:00              27              27
#
#                                   gdv_limitHi104  gdv_limitHi105  \
# 2025-08-18 20:38:14.114385+00:00              27              27
#
#                                   gdv_limitHi106  ...  temp_warnLo91  \
# 2025-08-18 20:38:14.114385+00:00              27  ...           -110
#
#                                   temp_warnLo92  temp_warnLo93  temp_warnLo94  \
# 2025-08-18 20:38:14.114385+00:00           -110           -110           -110
#
#                                   temp_warnLo95  temp_warnLo96  temp_warnLo97  \
# 2025-08-18 20:38:14.114385+00:00           -110           -110           -110
#
#                                   temp_warnLo98  temp_warnLo99  \
# 2025-08-18 20:38:14.114385+00:00           -110           -110
#
#                                                         version
# 2025-08-18 20:38:14.114385+00:00  Limits:FocalPlane/camera(d=6)
#
# [1 rows x 4826 columns]
# lsst.sal.MTCamera.logevent_focal_plane_ImageDatabaseService_GeneralConfiguration
#                                                                               dbURL  \
# 2025-08-18 20:38:14.174888+00:00  jdbc:mysql://lsstcam-db01:3306/ccsdbprod?user=...
#
#                                   enabled  \
# 2025-08-18 20:38:14.174888+00:00     True
#
#                                                                             version
# 2025-08-18 20:38:14.174888+00:00  General:FocalPlane/common(d=1)|FocalPlane/came...
# lsst.sal.MTCamera.logevent_focal_plane_ImageNameService_GeneralConfiguration
# query failed
#                                                                               dbURL  \
# 2025-08-18 20:38:14.174888+00:00  jdbc:mysql://lsstcam-db01:3306/ccsdbprod?user=...
#
#                                   enabled  \
# 2025-08-18 20:38:14.174888+00:00     True
#
#                                                                             version
# 2025-08-18 20:38:14.174888+00:00  General:FocalPlane/common(d=1)|FocalPlane/came...
# lsst.sal.MTCamera.logevent_focal_plane_InstrumentConfig_InstrumentConfiguration
#                                  instrument telescope testStand  \
# 2025-08-18 20:38:14.271511+00:00     Camera      LSST       BOT
#
#                                                                             version
# 2025-08-18 20:38:14.271511+00:00  Instrument:FocalPlane/camera(d=1)|FocalPlane/c...
# lsst.sal.MTCamera.logevent_focal_plane_MonitoringConfig_MonitoringConfiguration
#                                  postReadoutTriggerTasks readoutPauseTasks  \
# 2025-08-18 20:38:14.346543+00:00
#
#                                                                     version
# 2025-08-18 20:38:14.346543+00:00  Monitoring:FocalPlane/defaultInitial(d=1)
# lsst.sal.MTCamera.logevent_focal_plane_PeriodicTasks_GeneralConfiguration
#                                   schedulers_default_nTasks  \
# 2025-08-18 20:38:14.410031+00:00                         29
#
#                                   schedulers_default_nThreads  \
# 2025-08-18 20:38:14.410031+00:00                            8
#
#                                   schedulers_monitor_check_scheduler_nTasks  \
# 2025-08-18 20:38:14.410031+00:00                                         71
#
#                                   schedulers_monitor_check_scheduler_nThreads  \
# 2025-08-18 20:38:14.410031+00:00                                           18
#
#                                   schedulers_monitor_update_publish_scheduler_nTasks  \
# 2025-08-18 20:38:14.410031+00:00                                                822
#
#                                   schedulers_monitor_update_publish_scheduler_nThreads  \
# 2025-08-18 20:38:14.410031+00:00                                                103
#
#                                                                             version
# 2025-08-18 20:38:14.410031+00:00  General:FocalPlane/common(d=1)|FocalPlane/came...
# lsst.sal.MTCamera.logevent_focal_plane_PeriodicTasks_timersConfiguration
#                                   agentmonitorservice_taskPeriodMillis  \
# 2025-08-18 20:38:14.471403+00:00                                 60000
#
#                                   heartbeat_taskPeriodMillis  \
# 2025-08-18 20:38:14.471403+00:00                        1000
#
#                                   monitor_publish_taskPeriodMillis  \
# 2025-08-18 20:38:14.471403+00:00                              3000
#
#                                   monitor_update_taskPeriodMillis  \
# 2025-08-18 20:38:14.471403+00:00                             3000
#
#                                   runtimeinfo_taskPeriodMillis  \
# 2025-08-18 20:38:14.471403+00:00                         60000
#
#                                   tempcontrol_R00_taskPeriodMillis  \
# 2025-08-18 20:38:14.471403+00:00                              9000
#
#                                   tempcontrol_R01_taskPeriodMillis  \
# 2025-08-18 20:38:14.471403+00:00                              9000
#
#                                   tempcontrol_R02_taskPeriodMillis  \
# 2025-08-18 20:38:14.471403+00:00                              9000
#
#                                   tempcontrol_R03_taskPeriodMillis  \
# 2025-08-18 20:38:14.471403+00:00                              9000
#
#                                   tempcontrol_R04_taskPeriodMillis  ...  \
# 2025-08-18 20:38:14.471403+00:00                              9000  ...
#
#                                   tempcontrol_R31_taskPeriodMillis  \
# 2025-08-18 20:38:14.471403+00:00                              9000
#
#                                   tempcontrol_R32_taskPeriodMillis  \
# 2025-08-18 20:38:14.471403+00:00                              9000
#
#                                   tempcontrol_R33_taskPeriodMillis  \
# 2025-08-18 20:38:14.471403+00:00                              9000
#
#                                   tempcontrol_R34_taskPeriodMillis  \
# 2025-08-18 20:38:14.471403+00:00                              9000
#
# ...
# 2025-08-19 16:28:32.787625+00:00  6246.4  12.304688  23.99692       506.25
#
#                                   shtr_PLC1_V  shtr_PLC2_I  shtr_PLC2_V
# 2025-08-19 16:28:32.787625+00:00           24        237.5       24.025
#
# [1 rows x 25 columns]
# lsst.sal.MTCamera.quadbox_PDU_24VD
#                                   board_T  cryo_Turbo_I  cryo_Turbo_V  \
# 2025-08-19 16:28:42.855228+00:00       11         237.5        24.075
#
#                                   fes_Brakes_I  fes_Brakes_V  fes_ChangerD_I  \
# 2025-08-19 16:28:42.855228+00:00             0          24.1               0
#
#                                   fes_ChangerD_V  fes_Clamps_I  fes_Clamps_V  \
# 2025-08-19 16:28:42.855228+00:00          24.075             0        24.075
#
#                                   fes_LoaderD_I  fes_LoaderD_V  fpga_T  \
# 2025-08-19 16:28:42.855228+00:00              0          0.875      37
#
#                                   hex_Turbo_I  hex_Turbo_V  main_I     main_T  \
# 2025-08-19 16:28:42.855228+00:00        225.0       24.075  1073.6  11.328125
#
#                                     main_V  shtr_Brakes_I  shtr_Brakes_V
# 2025-08-19 16:28:42.855228+00:00  23.99692         718.75          24.05
# lsst.sal.MTCamera.quadbox_PDU_48V
#                                   board_T  fes_CarouselD_I  fes_CarouselD_V  \
# 2025-08-19 16:28:42.866349+00:00       10                0             47.9
#
#                                   fes_Heater_I  fes_Heater_V  fpga_T  main_I  \
# 2025-08-19 16:28:42.866349+00:00             0         0.825      33  1099.8
#
#                                      main_T    main_V  purge_Fan_I  \
# 2025-08-19 16:28:42.866349+00:00  13.769531  47.87804        837.5
#
#                                   purge_Fan_V  shtr_Motor1_I  shtr_Motor1_V  \
# 2025-08-19 16:28:42.866349+00:00        47.85            100           47.9
#
#                                   shtr_Motor2_I  shtr_Motor2_V
# 2025-08-19 16:28:42.866349+00:00            100         47.975
# lsst.sal.MTCamera.quadbox_PDU_5V
#                                    otm_0_A_I  otm_0_A_V  otm_0_B_I  otm_0_B_V  \
# 2025-08-19 16:28:40.889683+00:00  481.445313       5.35          0      0.525
#
#                                    otm_1_A_I  otm_1_A_V  otm_1_B_I  otm_1_B_V  \
# 2025-08-19 16:28:40.889683+00:00  480.957031       5.35          0       0.55
#
#                                    otm_2_A_I  otm_2_A_V  ...  otm_3_B_I  \
# 2025-08-19 16:28:40.889683+00:00  490.722656       5.35  ...   0.488281
#
#                                   otm_3_B_V   otm_4_A_I  otm_4_A_V  otm_4_B_I  \
# 2025-08-19 16:28:40.889683+00:00       0.55  492.675781      5.375          0
#
#                                   otm_4_B_V   otm_5_A_I  otm_5_A_V  otm_5_B_I  \
# 2025-08-19 16:28:40.889683+00:00       0.55  465.332031      5.375          0
#
#                                   otm_5_B_V
# 2025-08-19 16:28:40.889683+00:00      0.575
#
# [1 rows x 24 columns]
# lsst.sal.MTCamera.quadbox_REB_Bulk_PS
#                                   rebbulkps_0_2_I  rebbulkps_0_2_T  \
# 2025-08-19 16:28:51.390438+00:00           9221.4        18.652344
#
#                                   rebbulkps_0_2_V  rebbulkps_3_5_I  \
# 2025-08-19 16:28:51.390438+00:00         47.81032             9306
#
#                                   rebbulkps_3_5_T  rebbulkps_3_5_V  \
# 2025-08-19 16:28:51.390438+00:00        20.605469         47.94576
#
#                                   rebbulkps_6_8_I  rebbulkps_6_8_T  \
# 2025-08-19 16:28:51.390438+00:00           9277.8        16.699219
#
#                                   rebbulkps_6_8_V  rebbulkps_9_12_I  \
# 2025-08-19 16:28:51.390438+00:00         47.87804            8629.2
#
#                                   rebbulkps_9_12_T  rebbulkps_9_12_V  \
# 2025-08-19 16:28:51.390438+00:00         18.164062          47.87804
#
#                                   rebbulkps_Brd_T
# 2025-08-19 16:28:51.390438+00:00           16.125
# lsst.sal.MTCamera.rebpower_Reb
#                                   analog_IaftLDO0  analog_IaftLDO1  \
# 2025-08-19 16:29:27.152453+00:00           561.12          338.676
#
#                                   analog_IaftLDO10  analog_IaftLDO11  \
# 2025-08-19 16:29:27.152453+00:00           557.112           567.132
#
#                                   analog_IaftLDO12  analog_IaftLDO13  \
# 2025-08-19 16:29:27.152453+00:00           334.668           565.128
#
#                                   analog_IaftLDO14  analog_IaftLDO15  \
# 2025-08-19 16:29:27.152453+00:00           557.112           569.136
#
#                                   analog_IaftLDO16  analog_IaftLDO17  ...  \
# 2025-08-19 16:29:27.152453+00:00           565.128           533.064  ...
#
#                                     power64    power65    power66   power67  \
# 2025-08-19 16:29:27.152453+00:00  14.668529  19.693713  19.512913  15.06941
#
#                                     power68    power69     power7    power70  \
# 2025-08-19 16:29:27.152453+00:00  19.821303  14.142596  18.762669  10.322202
#
#                                      power8     power9
# 2025-08-19 16:29:27.152453+00:00  19.551034  14.907516
#
# [1 rows x 2821 columns]
# lsst.sal.MTCamera.rebpower_RebTotalPower
#                                   rebTotalPower
# 2025-08-19 16:29:27.166205+00:00    1157.320966
# lsst.sal.MTCamera.rebpower_Rebps
#                                   boardTemp00  boardTemp01  boardTemp010  \
# 2025-08-19 16:29:27.179606+00:00      13.6875      14.0625          10.5
#
#                                   boardTemp011  boardTemp012  boardTemp02  \
# 2025-08-19 16:29:27.179606+00:00         11.25         10.75         13.5
#
#                                   boardTemp03  boardTemp04  boardTemp05  \
# 2025-08-19 16:29:27.179606+00:00       10.625      11.9375        12.75
#
#                                   boardTemp06  ...  fPGATemp12  fPGATemp2  \
# 2025-08-19 16:29:27.179606+00:00      11.8125  ...   28.669012  32.852399
#
#                                   fPGATemp3  fPGATemp4  fPGATemp5  fPGATemp6  \
# 2025-08-19 16:29:27.179606+00:00  31.129828  33.221521  32.606317  31.375909
#
#                                   fPGATemp7  fPGATemp8  fPGATemp9  \
# 2025-08-19 16:29:27.179606+00:00  30.637665  29.530298  30.022461
#
#                                                                            location
# 2025-08-19 16:29:27.179606+00:00  P00:P01:P02:P03:P04:P05:P06:P07:P08:P09:P10:P1...
#
# [1 rows x 105 columns]
# lsst.sal.MTCamera.refrig_Cryo1
#                                   afterCoolTmp  compCurrent  compPower  \
# 2024-11-22 16:45:42.992955+00:00      20.03052         0.09     20.646
#
#                                   compVoltage  dischrgPrs  dischrgtmp_M  \
# 2024-11-22 16:45:42.992955+00:00        229.4        61.1     19.395697
#
#                                   dischrgtmp_P  fanSpeed  oilLevel  oilSepTmp  \
# 2024-11-22 16:45:42.992955+00:00         18.38      1180  11.98062  19.200366
#
#                                   phaseSepTmp  suctionPrs  suctiontmp_M  \
# 2024-11-22 16:45:42.992955+00:00    19.298031        61.6      19.63986
#
#                                   suctiontmp_P  surgeTankTmp  waterInTmp  \
# 2024-11-22 16:45:42.992955+00:00         19.49     37.756753   20.128186
#
#                                   waterOutTmp
# 2024-11-22 16:45:42.992955+00:00    19.542194
# lsst.sal.MTCamera.refrig_Cryo2
#                                   afterCoolTmp  compCurrent  compPower  \
# 2024-11-22 16:45:42.993046+00:00      5.771402          3.4      776.9
#
#                                   compVoltage  dischrgPrs  dischrgtmp_M  \
# 2024-11-22 16:45:42.993046+00:00        228.5       333.4    102.411109
#
#                                   dischrgtmp_P  fanSpeed  oilLevel  oilSepTmp  \
# 2024-11-22 16:45:42.993046+00:00        102.25      1170  -6.29028  92.791088
#
#                                   phaseSepTmp  suctionPrs  suctiontmp_M  \
# 2024-11-22 16:45:42.993046+00:00     5.283076        22.8      18.71204
#
#                                   suctiontmp_P  surgeTankTmp  waterInTmp  \
# 2024-11-22 16:45:42.993046+00:00         18.48     35.412788    5.283076
#
#                                   waterOutTmp
# 2024-11-22 16:45:42.993046+00:00    16.416908
# lsst.sal.MTCamera.refrig_Cryo3
#                                   afterCoolTmp  ambientTmp  cabinetTmp  \
# 2024-11-22 16:45:42.993095+00:00      5.869068   19.298031   21.495498
#
#                                   compCurrent  compPower  compVoltage  \
# 2024-11-22 16:45:42.993095+00:00         3.18    727.266        228.7
#
#                                   dischrgPrs  dischrgtmp_M  dischrgtmp_P  \
# 2024-11-22 16:45:42.993095+00:00       341.3     106.36655        107.64
#
#                                   fanSpeed  oilLevel  oilSepTmp  phaseSepTmp  \
# 2024-11-22 16:45:42.993095+00:00      1170  -6.74478  98.602167     5.869068
#
#                                   suctionPrs  suctiontmp_M  suctiontmp_P  \
# 2024-11-22 16:45:42.993095+00:00        21.6     19.542194         18.43
#
#                                   surgeTankTmp  waterInTmp  waterOutTmp
# 2024-11-22 16:45:42.993095+00:00     30.920189    5.331909    17.442393
# lsst.sal.MTCamera.refrig_Cryo4
#                                   afterCoolTmp compCurrent compPower  \
# 2024-11-22 16:45:42.993138+00:00      5.478407        None      None
#
#                                  compVoltage dischrgPrs  dischrgtmp_M  \
# 2024-11-22 16:45:42.993138+00:00        None       None     99.139325
#
#                                  dischrgtmp_P  fanSpeed oilLevel  oilSepTmp  \
# 2024-11-22 16:45:42.993138+00:00         None      1170     None  87.321837
#
#                                   phaseSepTmp suctionPrs  suctiontmp_M  \
# 2024-11-22 16:45:42.993138+00:00     4.990081       None      18.32138
#
#                                  suctiontmp_P  surgeTankTmp  waterInTmp  \
# 2024-11-22 16:45:42.993138+00:00         None     38.538074    5.136579
#
#                                   waterOutTmp
# 2024-11-22 16:45:42.993138+00:00    16.026248
# lsst.sal.MTCamera.refrig_Cryo5
#                                   afterCoolTmp  ambientTmp  cabinetTmp  \
# 2024-11-22 16:45:42.993183+00:00      5.527239   19.151534   21.593163
#
#                                   compCurrent  compPower  compVoltage  \
# 2024-11-22 16:45:42.993183+00:00         3.33    760.572        228.4
#
#                                   dischrgPrs  dischrgtmp_M  dischrgtmp_P  \
# 2024-11-22 16:45:42.993183+00:00       333.6     99.139325         96.33
#
#                                   fanSpeed  oilLevel  oilSepTmp  phaseSepTmp  \
# 2024-11-22 16:45:42.993183+00:00      1190   0.96354  87.273005     6.259728
#
#                                   suctionPrs  suctiontmp_M  suctiontmp_P  \
# 2024-11-22 16:45:42.993183+00:00        22.4     19.591027          17.5
#
#                                   surgeTankTmp  waterInTmp  waterOutTmp
# 2024-11-22 16:45:42.993183+00:00     35.119792    5.234244    17.930719
# lsst.sal.MTCamera.refrig_Cryo6
#                                   afterCoolTmp  compCurrent  compPower  \
# 2024-11-22 16:45:42.993233+00:00      4.697085         3.13    714.266
#
#                                   compVoltage  dischrgPrs  dischrgtmp_M  \
# 2024-11-22 16:45:42.993233+00:00        228.2       334.9    104.901572
#
#                                   dischrgtmp_P  fanSpeed  oilLevel oilSepTmp  \
# 2024-11-22 16:45:42.993233+00:00           105      1190  -5.58126      None
#
#                                   phaseSepTmp  suctionPrs  suctiontmp_M  \
# 2024-11-22 16:45:42.993233+00:00     5.966733        21.9      18.51671
#
#                                   suctiontmp_P  surgeTankTmp  waterInTmp  \
# 2024-11-22 16:45:42.993233+00:00         25.83     34.289638    5.234244
#
#                                   waterOutTmp
# 2024-11-22 16:45:42.993233+00:00    16.807569
# lsst.sal.MTCamera.utiltrunk_Body
#                                   ambAirtemp  averageTemp backFlngXMinusTemp  \
# 2025-08-19 16:30:05.447343+00:00    7.071713     7.446879               None
#
#                                  backFlngXPlusTemp backFlngYMinusTemp  \
# 2025-08-19 16:30:05.447343+00:00              None               None
#
#                                  camBodyXPlusTemp camBodyYMinusTemp  \
# 2025-08-19 16:30:05.447343+00:00             None              None
#
#                                  camBodyYPlusTemp camHousXMinusTemp  \
# 2025-08-19 16:30:05.447343+00:00             None              None
#
#                                  camHousXPlusTemp  ... l2YPlusTemp  \
# 2025-08-19 16:30:05.447343+00:00             None  ...        None
#
#                                  shrdRngXMinusTemp shrdRngXPlusTemp  \
# 2025-08-19 16:30:05.447343+00:00              None             None
#
#                                  shrdRngYMinusTemp shrdRngYPlusTemp  \
# 2025-08-19 16:30:05.447343+00:00              None             None
#
#                                  shtrEboxRtnAirTemp shtrEboxRtnAirVel  \
# 2025-08-19 16:30:05.447343+00:00               None              None
#
#                                  shtrMtrRtnAirTemp shtrMtrRtnAirVel  \
# 2025-08-19 16:30:05.447343+00:00              None             None
#
#                                  vPPlenumInTemp
# 2025-08-19 16:30:05.447343+00:00           None
#
# [1 rows x 31 columns]
# lsst.sal.MTCamera.utiltrunk_MPC
#                                   avgAirtempOut  deltaPressFilt  \
# 2025-08-19 16:30:15.459191+00:00      10.979878        0.124672
#
#                                   deltaPressTotal  deltaTempAct   fanRunTime  \
# 2025-08-19 16:30:15.459191+00:00         0.285433      4.007766  6326.841977
#
#                                   fanSpeed  humidity  preFiltPress  \
# 2025-08-19 16:30:15.459191+00:00      5280  9.580052      0.629921
#
#                                   retnAirTemp  retnPress  splyAirTemp  \
# 2025-08-19 16:30:15.459191+00:00     8.466135   0.354331     2.041833
#
#                                   splyPress  valvePosn
# 2025-08-19 16:30:15.459191+00:00   0.505249  77.427822
# lsst.sal.MTCamera.utiltrunk_UT
#                                   averageTemp  coolFlowRate  coolHeatXfer  \
# 2025-08-19 16:30:15.471036+00:00     5.895585      4.170604    790.514917
#
#                                   coolPipeRetnTemp  coolPipeSplyTemp  \
# 2025-08-19 16:30:15.471036+00:00          2.639442          1.643426
#
#                                  coolReturnPrs coolSupplyPrs  domeXMinusTemp  \
# 2025-08-19 16:30:15.471036+00:00          None          None       18.014763
#
#                                   domeYMinusTemp  fanInletTemp  ...  fanSpeed  \
# 2025-08-19 16:30:15.471036+00:00       17.939498      6.125498  ...      4860
#
#                                   midXMinusTemp  midXPlusTemp  suppXMinusTemp  \
# 2025-08-19 16:30:15.471036+00:00       4.648253      7.920037        5.283076
#
#                                   suppXPlusTemp  topXMinusTemp  topXPlusTemp  \
# 2025-08-19 16:30:15.471036+00:00       6.259728       5.527239        5.9179
#
#                                   valvePosn  w2Q1Temp  w4Q3Temp
# 2025-08-19 16:30:15.471036+00:00  80.774278  6.992217  5.331909
#
# [1 rows x 21 columns]
# lsst.sal.MTCamera.utiltrunk_VPC
#                                   deltaPressFilt  deltaPressTotal  \
# 2025-08-19 16:30:15.481647+00:00        0.209974         1.354987
#
#                                   deltaTempAct   fanRunTime  fanSpeed  \
# 2025-08-19 16:30:15.481647+00:00      0.474768  6513.518207      6180
#
#                                   htrCurrent  humidity  preFiltPress  \
# 2025-08-19 16:30:15.481647+00:00           0  6.135171      1.423885
#
#                                   retnAirTemp  retnPress  splyAirTemp  \
# 2025-08-19 16:30:15.481647+00:00     2.241036   0.062336     6.660105
#
#                                   splyAirVel  splyPress  valvePosn
# 2025-08-19 16:30:15.481647+00:00    0.013123    1.21063  74.048556

# %% [markdown]
# ## From here, you should be able to query consDB and/or EFD, and make the plots you need!
