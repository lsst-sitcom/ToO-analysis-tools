# %%
import lsst.alert.packet as packet
import os
import numpy as np
import pandas as pd
import urllib.request
import scipy as sp
import sys
# sys.path.append('/home/s/seanmacb/LSST-Camera/Extras and Utilities/pkgs')
# sys.path.append('/home/s/seanmacb/LSST-Camera/Extras and Utilities/pkgs/eo_pipe/python/lsst/eo/pipe')
# import eo_pipe.python.lsst.eo.pipe as eo_pipe
# from eo_pipe.python.lsst.eo.pipe import (readNoiseTask, darkCurrentTask, defectsTask, eperTask, divisaderoTearingTask, ptcPlotsTask,linearityPlotsTask, bfAnalysisTask)
import copy
import lsst.daf.butler as daf_butler
import lsst.afw.math as afw_math
from matplotlib import pyplot as plt
from lsst.ip.isr import IsrTask, IsrTaskConfig
plt.style.use("seaborn-v0_8-talk")
from matplotlib import lines
from mpl_toolkits import axes_grid1
from astropy.stats import sigma_clip
from scipy.stats import skew
import astropy
from tabulate import tabulate
from scipy.stats import norm


from lsst.obs.lsst import LsstCam, LsstTS8
from IPython.display import display_html, HTML
# import myutils_ar.myutils as myu

from astropy.time import Time
from collections import defaultdict
from datetime import datetime, timedelta
from scipy.stats import norm

# LSST Specific Libraries
from lsst_efd_client import EfdClient
from lsst.summit.utils.plotting import plot
from lsst.summit.utils.blockUtils import BlockParser
from lsst.summit.utils.efdUtils import makeEfdClient, getEfdData
from lsst.summit.utils.tmaUtils import (
    getCommandsDuringEvent,
    TMAEvent,
    TMAEventMaker,
    TMAState,
)
import matplotlib.dates as mdates

async def query_bump_logs_in_chunks(
    start_date,
    end_date,
    client_name="",
    chunk_size_days=3,
    topic_name="lsst.sal.MTM1M3.logevent_logMessage",
    fields=["message"],
):
    """
    Queries the log messages related to bump tests from the EFD in chunks.

    Args:
        start_date (str): Start date of the query in ISO format (YYYY-MM-DD).

        end_date (str): End date of the query in ISO format (YYYY-MM-DD).

        client_name (str, optional): Name of the EFD client. Defaults to "".

        chunk_size_days (int, optional): Number of days per chunk. Defaults to 3.

        topic_name (str, optional): SAL topic name to be queried by the client. Defaults to lsst.sal.MTM1M3.logevent_logMessage.

        fields (list[str], optional): Fields to be queried by the client. Defaults to ["message"].

    Returns:
        pandas.DataFrame: Concatenated DataFrame containing the queried log messages.
    """

    client = makeClient(client_name)

    # Convert start and end dates to datetime objects
    start = datetime.fromisoformat(start_date)
    end = datetime.fromisoformat(end_date)

    # Initialize an empty DataFrame to store concatenated results
    all_data = pd.DataFrame()

    current_start = start
    while current_start < end:
        current_end = min(current_start + timedelta(days=chunk_size_days), end)
        try:
            # Query the data for the current chunk
            chunk_data = await client.select_time_series(
                topic_name=topic_name,
                fields=fields,
                start=Time(current_start.isoformat(), format="isot", scale="utc"),
                end=Time(current_end.isoformat(), format="isot", scale="utc"),
            )
            # Concatenate the chunk data to the main DataFrame
            all_data = pd.concat([all_data, chunk_data], ignore_index=False)
        except Exception as e:
            print(
                f"Error querying data from {current_start.isoformat()} to {current_end.isoformat()}: {e}"
            )
            continue  # Optionally, continue to the next chunk

        # Move to the next chunk
        current_start = current_end

    return all_data

from astropy.utils.iers import conf
conf.auto_max_age = None

def makeClient(client_name):
    # Create the client based on client_name
    if client_name == "summit_efd":
        return makeEfdClient("summit_efd")
    elif client_name == "usdf_efd":
        return makeEfdClient("usdf_efd")
    elif client_name == "idf_efd":
        return makeEfdClient("idf_efd")
    else:
        return makeEfdClient()  # Default client

import healpy as hp

# Example usage:
# begin = "2023-11-13T01:00"
# end = "2023-12-21T01:00"
# bump_logs = await query_bump_logs_in_chunks(begin, end, client_name='')

import lsst.afw.display as afwDisplay
afwDisplay.setDefaultBackend('matplotlib') 
def showAndClear():
    plt.show()
    # Clear the current axes.
    plt.cla()
    # Clear the current figure.
    plt.clf()
    # Closes all the figure windows.
    plt.close("all")
    plt.close(fig)

    return


async def getDataFrame(client, starts, ends, topic, verbose=True, fields=None):

    all_data = pd.DataFrame()
    for start, end in zip(starts, ends):
        if verbose:
            print(
                r"Starting query for time range {} - {}".format(start, end),
                end=" . . . ",
            )
        if fields != None:
            df_bump = await client.select_time_series(
                topic, fields, Time(start), Time(end)
            )
        else:
            df_bump = await client.select_time_series(
                topic, "*", Time(start), Time(end)
            )

        all_data = pd.concat([all_data, df_bump], ignore_index=False)

        del df_bump

        if verbose:
            print("Finished")

    return all_data


def makeDateRange(startPoint, endPoint, step=np.timedelta64(1, "D")):
    starts = np.arange(startPoint, endPoint, step=step)
    ends = starts + np.timedelta64(1, "D")
    return starts, ends

def fitGaussian(data, ax):
    mu, std = norm.fit(data)

    xmin, xmax = ax.get_xlim()
    x = np.linspace(np.floor(xmin), np.ceil(xmax), int(10e4))
    p = norm.pdf(x, mu, std)

    return mu, std, p, x, xmin, xmax

def getFWHM_from_gaussian(sigma):
    return 2 * np.sqrt(np.log(2) * 2) * sigma

from astropy.time import Time
from astropy.coordinates import get_sun
import astropy.coordinates as coord
import astropy.units as u



from astropy.stats import mad_std
instrument="LSSTCam"
# embargoButler = daf_butler.Butler("/repo/embargo",collections=['LSSTCam/raw/all','LSSTCam/calib'])
# mainButler = daf_butler.Butler("/repo/main",collections=['LSSTCam/raw/all','LSSTCam/calib/unbounded'])
# flatColl = "LSSTCam/calib/DM-50448/initial-ugr-flats/flatGen-u.20250423a"
# flat_det184 = embargoButler.get("flat",collections=flatColl,detector=184,instrument=instrument,physical_filter="i_39")
isrConfig = IsrTaskConfig()
isrConfig.doLinearize=False
isrConfig.doOverscan=True
isrConfig.overscan.fitType="MEDIAN_PER_ROW"
isrConfig.overscan.doParallelOverscan=True
isrConfig.doAssembleCcd=True
isrConfig.doBias=False
isrConfig.doVariance=False
isrConfig.doCrosstalk=False
isrConfig.doBrighterFatter=False
isrConfig.doDark=False
isrConfig.doStrayLight=False
isrConfig.doFlat=False
isrConfig.doFringe=False
isrConfig.doApplyGains=True
isrConfig.usePtcGains=False
isrConfig.doDefect=False
isrConfig.doNanMasking=True
isrConfig.doInterpolate=False
isrConfig.doSaturation=False
isrConfig.doSaturationInterpolation=False
isrTask = IsrTask(config=isrConfig)

# %%
uri = packet.get_uri_to_latest_schema()
schem = packet.Schema.from_uri(uri)

# %%
schem.definition
# Out:
# {'type': 'record',
#  'doc': 'Rubin Avro alert schema v7.4',
#  'name': 'lsst.v7_4.alert',
#  'fields': [{'doc': 'unique alert identifer',
#    'name': 'alertId',
#    'type': 'long'},
#   {'name': 'diaSource',
#    'type': {'type': 'record',
#     'name': 'lsst.v7_4.diaSource',
#     'fields': [{'doc': 'Unique identifier of this DiaSource.',
#       'name': 'diaSourceId',
#       'type': 'long'},
#      {'doc': 'Id of the visit where this diaSource was measured.',
#       'name': 'visit',
#       'type': 'long'},
#      {'doc': 'Id of the detector where this diaSource was measured. Datatype short instead of byte because of DB concerns about unsigned bytes.',
#       'name': 'detector',
#       'type': 'int'},
#      {'default': None,
#       'doc': 'Id of the diaObject this source was associated with, if any. If not, it is set to NULL (each diaSource will be associated with either a diaObject or ssObject).',
#       'name': 'diaObjectId',
#       'type': ['null', 'long']},
#      {'default': None,
#       'doc': 'Id of the ssObject this source was associated with, if any. If not, it is set to NULL (each diaSource will be associated with either a diaObject or ssObject).',
#       'name': 'ssObjectId',
#       'type': ['null', 'long']},
#      {'default': None,
#       'doc': 'Id of the parent diaSource this diaSource has been deblended from, if any.',
#       'name': 'parentDiaSourceId',
#       'type': ['null', 'long']},
#      {'doc': 'Effective mid-visit time for this diaSource, expressed as Modified Julian Date, International Atomic Time.',
#       'name': 'midpointMjdTai',
#       'type': 'double'},
#      {'doc': 'Right ascension coordinate of the center of this diaSource.',
#       'name': 'ra',
#       'type': 'double'},
#      {'default': None,
#       'doc': 'Uncertainty of ra.',
#       'name': 'raErr',
#       'type': ['null', 'float']},
#      {'doc': 'Declination coordinate of the center of this diaSource.',
#       'name': 'dec',
#       'type': 'double'},
#      {'default': None,
#       'doc': 'Uncertainty of dec.',
#       'name': 'decErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance between ra and dec.',
#       'name': 'ra_dec_Cov',
#       'type': ['null', 'float']},
#      {'doc': 'x position computed by a centroiding algorithm.',
#       'name': 'x',
#       'type': 'float'},
#      {'default': None,
#       'doc': 'Uncertainty of x.',
#       'name': 'xErr',
#       'type': ['null', 'float']},
#      {'doc': 'y position computed by a centroiding algorithm.',
#       'name': 'y',
#       'type': 'float'},
#      {'default': None,
#       'doc': 'Uncertainty of y.',
#       'name': 'yErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance between x and y.',
#       'name': 'x_y_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'General centroid algorithm failure flag; set if anything went wrong when fitting the centroid. Another centroid flag field should also be set to provide more information.',
#       'name': 'centroid_flag',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Flux in a 12 pixel radius aperture on the difference image.',
#       'name': 'apFlux',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Estimated uncertainty of apFlux.',
#       'name': 'apFluxErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'General aperture flux algorithm failure flag; set if anything went wrong when measuring aperture fluxes. Another apFlux flag field should also be set to provide more information.',
#       'name': 'apFlux_flag',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Aperture did not fit within measurement image.',
#       'name': 'apFlux_flag_apertureTruncated',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Source was detected as significantly negative.',
#       'name': 'is_negative',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'The signal-to-noise ratio at which this source was detected in the difference image.',
#       'name': 'snr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Flux for Point Source model. Note this actually measures the flux difference between the template and the visit image.',
#       'name': 'psfFlux',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Uncertainty of psfFlux.',
#       'name': 'psfFluxErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Right ascension coordinate of centroid for point source model.',
#       'name': 'psfRa',
#       'type': ['null', 'double']},
#      {'default': None,
#       'doc': 'Uncertainty of psfRa.',
#       'name': 'psfRaErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Declination coordinate of centroid for point source model.',
#       'name': 'psfDec',
#       'type': ['null', 'double']},
#      {'default': None,
#       'doc': 'Uncertainty of psfDec.',
#       'name': 'psfDecErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance between psfFlux and psfRa.',
#       'name': 'psfFlux_psfRa_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance between psfFlux and psfDec.',
#       'name': 'psfFlux_psfDec_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance between psfRa and psfDec.',
#       'name': 'psfRa_psfDec_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Natural log likelihood of the observed data given the point source model.',
#       'name': 'psfLnL',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Chi^2 statistic of the point source model fit.',
#       'name': 'psfChi2',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'The number of data points (pixels) used to fit the point source model.',
#       'name': 'psfNdata',
#       'type': ['null', 'int']},
#      {'default': None,
#       'doc': 'Failure to derive linear least-squares fit of psf model. Another psfFlux flag field should also be set to provide more information.',
#       'name': 'psfFlux_flag',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Object was too close to the edge of the image to use the full PSF model.',
#       'name': 'psfFlux_flag_edge',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Not enough non-rejected pixels in data to attempt the fit.',
#       'name': 'psfFlux_flag_noGoodPixels',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Flux for a trailed source model. Note this actually measures the flux difference between the template and the visit image.',
#       'name': 'trailFlux',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Uncertainty of trailFlux.',
#       'name': 'trailFluxErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Right ascension coordinate of centroid for trailed source model.',
#       'name': 'trailRa',
#       'type': ['null', 'double']},
#      {'default': None,
#       'doc': 'Uncertainty of trailRa.',
#       'name': 'trailRaErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Declination coordinate of centroid for trailed source model.',
#       'name': 'trailDec',
#       'type': ['null', 'double']},
#      {'default': None,
#       'doc': 'Uncertainty of trailDec.',
#       'name': 'trailDecErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Maximum likelihood fit of trail length.',
#       'name': 'trailLength',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Uncertainty of trailLength.',
#       'name': 'trailLengthErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Maximum likelihood fit of the angle between the meridian through the centroid and the trail direction (bearing).',
#       'name': 'trailAngle',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Uncertainty of trailAngle.',
#       'name': 'trailAngleErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of trailFlux and trailRa.',
#       'name': 'trailFlux_trailRa_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of trailFlux and trailDec.',
#       'name': 'trailFlux_trailDec_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of trailFlux and trailLength',
#       'name': 'trailFlux_trailLength_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of trailFlux and trailAngle',
#       'name': 'trailFlux_trailAngle_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of trailRa and trailDec.',
#       'name': 'trailRa_trailDec_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of trailRa and trailLength.',
#       'name': 'trailRa_trailLength_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of trailRa and trailAngle.',
#       'name': 'trailRa_trailAngle_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of trailDec and trailLength.',
#       'name': 'trailDec_trailLength_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of trailDec and trailAngle.',
#       'name': 'trailDec_trailAngle_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of trailLength and trailAngle',
#       'name': 'trailLength_trailAngle_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Natural log likelihood of the observed data given the trailed source model.',
#       'name': 'trailLnL',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Chi^2 statistic of the trailed source model fit.',
#       'name': 'trailChi2',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'The number of data points (pixels) used to fit the trailed source model.',
#       'name': 'trailNdata',
#       'type': ['null', 'int']},
#      {'default': None,
#       'doc': 'This flag is set if a trailed source extends onto or past edge pixels.',
#       'name': 'trail_flag_edge',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Maximum likelihood value for the mean absolute flux of the two lobes for a dipole model.',
#       'name': 'dipoleMeanFlux',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Uncertainty of dipoleMeanFlux.',
#       'name': 'dipoleMeanFluxErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Maximum likelihood value for the difference of absolute fluxes of the two lobes for a dipole model.',
#       'name': 'dipoleFluxDiff',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Uncertainty of dipoleFluxDiff.',
#       'name': 'dipoleFluxDiffErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Right ascension coordinate of centroid for dipole model.',
#       'name': 'dipoleRa',
#       'type': ['null', 'double']},
#      {'default': None,
#       'doc': 'Uncertainty of dipoleRa.',
#       'name': 'dipoleRaErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Declination coordinate of centroid for dipole model.',
#       'name': 'dipoleDec',
#       'type': ['null', 'double']},
#      {'default': None,
#       'doc': 'Uncertainty of dipoleDec.',
#       'name': 'dipoleDecErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Maximum likelihood value for the lobe separation in dipole model.',
#       'name': 'dipoleLength',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Uncertainty of dipoleLength.',
#       'name': 'dipoleLengthErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Maximum likelihood fit of the angle between the meridian through the centroid and the dipole direction (bearing, from negative to positive lobe).',
#       'name': 'dipoleAngle',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Uncertainty of dipoleAngle.',
#       'name': 'dipoleAngleErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleMeanFlux and dipoleFluxDiff.',
#       'name': 'dipoleMeanFlux_dipoleFluxDiff_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleMeanFlux and dipoleRa.',
#       'name': 'dipoleMeanFlux_dipoleRa_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleMeanFlux and dipoleDec.',
#       'name': 'dipoleMeanFlux_dipoleDec_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleMeanFlux and dipoleLength.',
#       'name': 'dipoleMeanFlux_dipoleLength_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleMeanFlux and dipoleAngle.',
#       'name': 'dipoleMeanFlux_dipoleAngle_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleFluxDiff and dipoleRa.',
#       'name': 'dipoleFluxDiff_dipoleRa_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleFluxDiff and dipoleDec.',
#       'name': 'dipoleFluxDiff_dipoleDec_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleFluxDiff and dipoleLength.',
#       'name': 'dipoleFluxDiff_dipoleLength_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleFluxDiff and dipoleAngle.',
#       'name': 'dipoleFluxDiff_dipoleAngle_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleRa and dipoleDec.',
#       'name': 'dipoleRa_dipoleDec_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleRa and dipoleLength.',
#       'name': 'dipoleRa_dipoleLength_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleRa and dipoleAngle.',
#       'name': 'dipoleRa_dipoleAngle_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleDec and dipoleLength.',
#       'name': 'dipoleDec_dipoleLength_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleDec and dipoleAngle.',
#       'name': 'dipoleDec_dipoleAngle_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of dipoleLength and dipoleAngle.',
#       'name': 'dipoleLength_dipoleAngle_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Natural log likelihood of the observed data given the dipole source model.',
#       'name': 'dipoleLnL',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Chi^2 statistic of the model fit.',
#       'name': 'dipoleChi2',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'The number of data points (pixels) used to fit the model.',
#       'name': 'dipoleNdata',
#       'type': ['null', 'int']},
#      {'default': None,
#       'doc': 'Forced PSF photometry on science image failed. Another forced_PsfFlux flag field should also be set to provide more information.',
#       'name': 'forced_PsfFlux_flag',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Forced PSF flux on science image was too close to the edge of the image to use the full PSF model.',
#       'name': 'forced_PsfFlux_flag_edge',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Forced PSF flux not enough non-rejected pixels in data to attempt the fit.',
#       'name': 'forced_PsfFlux_flag_noGoodPixels',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Calibrated flux for Point Source model centered on radec but measured on the difference of snaps comprising this visit.',
#       'name': 'snapDiffFlux',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Estimated uncertainty of snapDiffFlux.',
#       'name': 'snapDiffFluxErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Estimated sky background at the position (centroid) of the object.',
#       'name': 'fpBkgd',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Estimated uncertainty of fpBkgd.',
#       'name': 'fpBkgdErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Adaptive second moment of the source intensity.',
#       'name': 'ixx',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Uncertainty of ixx.',
#       'name': 'ixxErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Adaptive second moment of the source intensity.',
#       'name': 'iyy',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Uncertainty of iyy.',
#       'name': 'iyyErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Adaptive second moment of the source intensity.',
#       'name': 'ixy',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Uncertainty of ixy.',
#       'name': 'ixyErr',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of ixx and iyy.',
#       'name': 'ixx_iyy_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of ixx and ixy.',
#       'name': 'ixx_ixy_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Covariance of iyy and ixy.',
#       'name': 'iyy_ixy_Cov',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Adaptive second moment for the PSF.',
#       'name': 'ixxPSF',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Adaptive second moment for the PSF.',
#       'name': 'iyyPSF',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Adaptive second moment for the PSF.',
#       'name': 'ixyPSF',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'General source shape algorithm failure flag; set if anything went wrong when measuring the shape. Another shape flag field should also be set to provide more information.',
#       'name': 'shape_flag',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'No pixels to measure shape.',
#       'name': 'shape_flag_no_pixels',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Center not contained in footprint bounding box.',
#       'name': 'shape_flag_not_contained',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'This source is a parent source; we should only be measuring on deblended children in difference imaging.',
#       'name': 'shape_flag_parent_source',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': "A measure of extendedness, computed by comparing an object's moment-based traced radius to the PSF moments. extendedness = 1 implies a high degree of confidence that the source is extended. extendedness = 0 implies a high degree of confidence that the source is point-like.",
#       'name': 'extendedness',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'A measure of reliability, computed using information from the source and image characterization, as well as the information on the Telescope and Camera system (e.g., ghost maps, defect maps, etc.).',
#       'name': 'reliability',
#       'type': ['null', 'float']},
#      {'default': None,
#       'doc': 'Filter band this source was observed with.',
#       'name': 'band',
#       'type': ['null', 'string']},
#      {'default': None,
#       'doc': 'Attempted to fit a dipole model to this source.',
#       'name': 'dipoleFitAttempted',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': "General pixel flags failure; set if anything went wrong when setting pixels flags from this footprint's mask. This implies that some pixelFlags for this source may be incorrectly set to False.",
#       'name': 'pixelFlags',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Bad pixel in the DiaSource footprint.',
#       'name': 'pixelFlags_bad',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Cosmic ray in the DiaSource footprint.',
#       'name': 'pixelFlags_cr',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Cosmic ray in the 3x3 region around the centroid.',
#       'name': 'pixelFlags_crCenter',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Some of the source footprint is outside usable exposure region (masked EDGE or centroid off image).',
#       'name': 'pixelFlags_edge',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'NO_DATA pixel in the source footprint.',
#       'name': 'pixelFlags_nodata',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'NO_DATA pixel in the 3x3 region around the centroid.',
#       'name': 'pixelFlags_nodataCenter',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Interpolated pixel in the DiaSource footprint.',
#       'name': 'pixelFlags_interpolated',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Interpolated pixel in the 3x3 region around the centroid.',
#       'name': 'pixelFlags_interpolatedCenter',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'DiaSource center is off image.',
#       'name': 'pixelFlags_offimage',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Saturated pixel in the DiaSource footprint.',
#       'name': 'pixelFlags_saturated',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Saturated pixel in the 3x3 region around the centroid.',
#       'name': 'pixelFlags_saturatedCenter',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': "DiaSource's footprint includes suspect pixels.",
#       'name': 'pixelFlags_suspect',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Suspect pixel in the 3x3 region around the centroid.',
#       'name': 'pixelFlags_suspectCenter',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Streak in the DiaSource footprint.',
#       'name': 'pixelFlags_streak',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Streak in the 3x3 region around the centroid.',
#       'name': 'pixelFlags_streakCenter',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Injection in the DiaSource footprint.',
#       'name': 'pixelFlags_injected',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Injection in the 3x3 region around the centroid.',
#       'name': 'pixelFlags_injectedCenter',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Template injection in the DiaSource footprint.',
#       'name': 'pixelFlags_injected_template',
#       'type': ['null', 'boolean']},
#      {'default': None,
#       'doc': 'Template injection in the 3x3 region around the centroid.',
#       'name': 'pixelFlags_injected_templateCenter',
#       'type': ['null', 'boolean']}]}},
#   {'default': None,
#    'name': 'prvDiaSources',
#    'type': ['null', {'type': 'array', 'items': 'lsst.v7_4.diaSource'}]},
#   {'default': None,
#    'name': 'prvDiaForcedSources',
#    'type': ['null',
#     {'type': 'array',
#      'items': {'type': 'record',
#       'name': 'lsst.v7_4.diaForcedSource',
#       'fields': [{'doc': 'Unique id.',
#         'name': 'diaForcedSourceId',
#         'type': 'long'},
#        {'doc': 'Id of the DiaObject that this DiaForcedSource was associated with.',
#         'name': 'diaObjectId',
#         'type': 'long'},
#        {'doc': 'Right ascension coordinate of the position of the DiaObject at time radecMjdTai.',
#         'name': 'ra',
#         'type': 'double'},
#        {'doc': 'Declination coordinate of the position of the DiaObject at time radecMjdTai.',
#         'name': 'dec',
#         'type': 'double'},
#        {'doc': 'Id of the visit where this forcedSource was measured.',
#         'name': 'visit',
#         'type': 'long'},
#        {'doc': 'Id of the detector where this forcedSource was measured. Datatype short instead of byte because of DB concerns about unsigned bytes.',
#         'name': 'detector',
#         'type': 'int'},
#        {'default': None,
#         'doc': 'Point Source model flux.',
#         'name': 'psfFlux',
#         'type': ['null', 'float']},
#        {'default': None,
#         'doc': 'Uncertainty of psfFlux.',
#         'name': 'psfFluxErr',
#         'type': ['null', 'float']},
#        {'doc': 'Effective mid-visit time for this diaForcedSource, expressed as Modified Julian Date, International Atomic Time.',
#         'name': 'midpointMjdTai',
#         'type': 'double'},
#        {'default': None,
#         'doc': 'Filter band this source was observed with.',
#         'name': 'band',
#         'type': ['null', 'string']}]}}]},
#   {'default': None,
#    'name': 'prvDiaNondetectionLimits',
#    'type': ['null',
#     {'type': 'array',
#      'items': {'type': 'record',
#       'name': 'lsst.v7_4.diaNondetectionLimit',
#       'fields': [{'name': 'ccdVisitId', 'type': 'long'},
#        {'name': 'midpointMjdTai', 'type': 'double'},
#        {'name': 'band', 'type': 'string'},
#        {'name': 'diaNoise', 'type': 'float'}]}}]},
#   {'default': None,
#    'name': 'diaObject',
#    'type': ['null',
#     {'type': 'record',
#      'name': 'lsst.v7_4.diaObject',
#      'fields': [{'doc': 'Unique identifier of this DiaObject.',
#        'name': 'diaObjectId',
#        'type': 'long'},
#       {'doc': 'Right ascension coordinate of the position of the object at time radecMjdTai.',
#        'name': 'ra',
#        'type': 'double'},
#       {'default': None,
#        'doc': 'Uncertainty of ra.',
#        'name': 'raErr',
#        'type': ['null', 'float']},
#       {'doc': 'Declination coordinate of the position of the object at time radecMjdTai.',
#        'name': 'dec',
#        'type': 'double'},
#       {'default': None,
#        'doc': 'Uncertainty of dec.',
#        'name': 'decErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Covariance between ra and dec.',
#        'name': 'ra_dec_Cov',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Time at which the object was at a position ra/dec, expressed as Modified Julian Date, International Atomic Time.',
#        'name': 'radecMjdTai',
#        'type': ['null', 'double']},
#       {'default': None,
#        'doc': 'Proper motion in right ascension.',
#        'name': 'pmRa',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of pmRa.',
#        'name': 'pmRaErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Proper motion of declination.',
#        'name': 'pmDec',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of pmDec.',
#        'name': 'pmDecErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Parallax.',
#        'name': 'parallax',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of parallax.',
#        'name': 'parallaxErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Covariance of pmRa and pmDec.',
#        'name': 'pmRa_pmDec_Cov',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Covariance of pmRa and parallax.',
#        'name': 'pmRa_parallax_Cov',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Covariance of pmDec and parallax.',
#        'name': 'pmDec_parallax_Cov',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Natural log of the likelihood of the linear proper motion parallax fit.',
#        'name': 'pmParallaxLnL',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Chi^2 static of the model fit.',
#        'name': 'pmParallaxChi2',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'The number of data points used to fit the model.',
#        'name': 'pmParallaxNdata',
#        'type': ['null', 'int']},
#       {'default': None,
#        'doc': 'Weighted mean point-source model magnitude for u filter.',
#        'name': 'u_psfFluxMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard error of u_psfFluxMean.',
#        'name': 'u_psfFluxMeanErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard deviation of the distribution of u_psfFlux.',
#        'name': 'u_psfFluxSigma',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Chi^2 statistic for the scatter of u_psfFlux around u_psfFluxMean.',
#        'name': 'u_psfFluxChi2',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'The number of data points used to compute u_psfFluxChi2.',
#        'name': 'u_psfFluxNdata',
#        'type': ['null', 'int']},
#       {'default': None,
#        'doc': 'Weighted mean forced photometry flux for u filter.',
#        'name': 'u_fpFluxMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard error of u_fpFluxMean.',
#        'name': 'u_fpFluxMeanErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard deviation of the distribution of u_fpFlux.',
#        'name': 'u_fpFluxSigma',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Weighted mean point-source model magnitude for g filter.',
#        'name': 'g_psfFluxMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard error of g_psfFluxMean.',
#        'name': 'g_psfFluxMeanErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard deviation of the distribution of g_psfFlux.',
#        'name': 'g_psfFluxSigma',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Chi^2 statistic for the scatter of g_psfFlux around g_psfFluxMean.',
#        'name': 'g_psfFluxChi2',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'The number of data points used to compute g_psfFluxChi2.',
#        'name': 'g_psfFluxNdata',
#        'type': ['null', 'int']},
#       {'default': None,
#        'doc': 'Weighted mean forced photometry flux for g filter.',
#        'name': 'g_fpFluxMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard error of g_fpFluxMean.',
#        'name': 'g_fpFluxMeanErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard deviation of the distribution of g_fpFlux.',
#        'name': 'g_fpFluxSigma',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Weighted mean point-source model magnitude for r filter.',
#        'name': 'r_psfFluxMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard error of r_psfFluxMean.',
#        'name': 'r_psfFluxMeanErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard deviation of the distribution of r_psfFlux.',
#        'name': 'r_psfFluxSigma',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Chi^2 statistic for the scatter of r_psfFlux around r_psfFluxMean.',
#        'name': 'r_psfFluxChi2',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'The number of data points used to compute r_psfFluxChi2.',
#        'name': 'r_psfFluxNdata',
#        'type': ['null', 'int']},
#       {'default': None,
#        'doc': 'Weighted mean forced photometry flux for r filter.',
#        'name': 'r_fpFluxMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard error of r_fpFluxMean.',
#        'name': 'r_fpFluxMeanErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard deviation of the distribution of r_fpFlux.',
#        'name': 'r_fpFluxSigma',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Weighted mean point-source model magnitude for i filter.',
#        'name': 'i_psfFluxMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard error of i_psfFluxMean.',
#        'name': 'i_psfFluxMeanErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard deviation of the distribution of i_psfFlux.',
#        'name': 'i_psfFluxSigma',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Chi^2 statistic for the scatter of i_psfFlux around i_psfFluxMean.',
#        'name': 'i_psfFluxChi2',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'The number of data points used to compute i_psfFluxChi2.',
#        'name': 'i_psfFluxNdata',
#        'type': ['null', 'int']},
#       {'default': None,
#        'doc': 'Weighted mean forced photometry flux for i filter.',
#        'name': 'i_fpFluxMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard error of i_fpFluxMean.',
#        'name': 'i_fpFluxMeanErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard deviation of the distribution of i_fpFlux.',
#        'name': 'i_fpFluxSigma',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Weighted mean point-source model magnitude for z filter.',
#        'name': 'z_psfFluxMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard error of z_psfFluxMean.',
#        'name': 'z_psfFluxMeanErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard deviation of the distribution of z_psfFlux.',
#        'name': 'z_psfFluxSigma',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Chi^2 statistic for the scatter of z_psfFlux around z_psfFluxMean.',
#        'name': 'z_psfFluxChi2',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'The number of data points used to compute z_psfFluxChi2.',
#        'name': 'z_psfFluxNdata',
#        'type': ['null', 'int']},
#       {'default': None,
#        'doc': 'Weighted mean forced photometry flux for z filter.',
#        'name': 'z_fpFluxMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard error of z_fpFluxMean.',
#        'name': 'z_fpFluxMeanErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard deviation of the distribution of z_fpFlux.',
#        'name': 'z_fpFluxSigma',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Weighted mean point-source model magnitude for y filter.',
#        'name': 'y_psfFluxMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard error of y_psfFluxMean.',
#        'name': 'y_psfFluxMeanErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard deviation of the distribution of y_psfFlux.',
#        'name': 'y_psfFluxSigma',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Chi^2 statistic for the scatter of y_psfFlux around y_psfFluxMean.',
#        'name': 'y_psfFluxChi2',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'The number of data points used to compute y_psfFluxChi2.',
#        'name': 'y_psfFluxNdata',
#        'type': ['null', 'int']},
#       {'default': None,
#        'doc': 'Weighted mean forced photometry flux for y filter.',
#        'name': 'y_fpFluxMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard error of y_fpFluxMean.',
#        'name': 'y_fpFluxMeanErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Standard deviation of the distribution of y_fpFlux.',
#        'name': 'y_fpFluxSigma',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Id of the closest nearby object.',
#        'name': 'nearbyObj1',
#        'type': ['null', 'long']},
#       {'default': None,
#        'doc': 'Distance to nearbyObj1.',
#        'name': 'nearbyObj1Dist',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Natural log of the probability that the observed diaObject is the same as the nearbyObj1.',
#        'name': 'nearbyObj1LnP',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Id of the second-closest nearby object.',
#        'name': 'nearbyObj2',
#        'type': ['null', 'long']},
#       {'default': None,
#        'doc': 'Distance to nearbyObj2.',
#        'name': 'nearbyObj2Dist',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Natural log of the probability that the observed diaObject is the same as the nearbyObj2.',
#        'name': 'nearbyObj2LnP',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Id of the third-closest nearby object.',
#        'name': 'nearbyObj3',
#        'type': ['null', 'long']},
#       {'default': None,
#        'doc': 'Distance to nearbyObj3.',
#        'name': 'nearbyObj3Dist',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Natural log of the probability that the observed diaObject is the same as the nearbyObj3.',
#        'name': 'nearbyObj3LnP',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Mean of the u band flux errors.',
#        'name': 'u_psfFluxErrMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Mean of the g band flux errors.',
#        'name': 'g_psfFluxErrMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Mean of the r band flux errors.',
#        'name': 'r_psfFluxErrMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Mean of the i band flux errors.',
#        'name': 'i_psfFluxErrMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Mean of the z band flux errors.',
#        'name': 'z_psfFluxErrMean',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Mean of the y band flux errors.',
#        'name': 'y_psfFluxErrMean',
#        'type': ['null', 'float']}]}]},
#   {'default': None,
#    'name': 'ssObject',
#    'type': ['null',
#     {'type': 'record',
#      'name': 'lsst.v7_4.ssObject',
#      'fields': [{'doc': 'Unique identifier.',
#        'name': 'ssObjectId',
#        'type': 'long'},
#       {'default': None,
#        'doc': 'The date the LSST first linked and submitted the discovery observations to the MPC. May be NULL if not an LSST discovery. The date format will follow general LSST conventions (MJD TAI, at the moment).',
#        'name': 'discoverySubmissionDate',
#        'type': ['null', 'double']},
#       {'default': None,
#        'doc': 'The time of the first LSST observation of this object (could be precovered) as Modified Julian Date, International Atomic Time.',
#        'name': 'firstObservationDate',
#        'type': ['null', 'double']},
#       {'default': None,
#        'doc': 'Arc of LSST observations.',
#        'name': 'arc',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Number of LSST observations of this object.',
#        'name': 'numObs',
#        'type': ['null', 'int']},
#       {'default': None,
#        'doc': 'Minimum orbit intersection distance to Earth.',
#        'name': 'MOID',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'True anomaly of the MOID point.',
#        'name': 'MOIDTrueAnomaly',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Ecliptic longitude of the MOID point.',
#        'name': 'MOIDEclipticLongitude',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'DeltaV at the MOID point.',
#        'name': 'MOIDDeltaV',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Best fit absolute magnitude (u band).',
#        'name': 'u_H',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Best fit G12 slope parameter (u band).',
#        'name': 'u_G12',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of H (u band).',
#        'name': 'u_HErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of G12 (u band).',
#        'name': 'u_G12Err',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'H-G12 covariance (u band).',
#        'name': 'u_H_u_G12_Cov',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Chi^2 statistic of the phase curve fit (u band).',
#        'name': 'u_Chi2',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'The number of data points used to fit the phase curve (u band).',
#        'name': 'u_Ndata',
#        'type': ['null', 'int']},
#       {'default': None,
#        'doc': 'Best fit absolute magnitude (g band).',
#        'name': 'g_H',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Best fit G12 slope parameter (g band).',
#        'name': 'g_G12',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of H (g band).',
#        'name': 'g_HErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of G12 (g band).',
#        'name': 'g_G12Err',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'H-G12 covariance (g band).',
#        'name': 'g_H_g_G12_Cov',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Chi^2 statistic of the phase curve fit (g band).',
#        'name': 'g_Chi2',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'The number of data points used to fit the phase curve (g band).',
#        'name': 'g_Ndata',
#        'type': ['null', 'int']},
#       {'default': None,
#        'doc': 'Best fit absolute magnitude (r band).',
#        'name': 'r_H',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Best fit G12 slope parameter (r band).',
#        'name': 'r_G12',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of H (r band).',
#        'name': 'r_HErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of G12 (r band).',
#        'name': 'r_G12Err',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'H-G12 covariance (r band).',
#        'name': 'r_H_r_G12_Cov',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Chi^2 statistic of the phase curve fit (r band).',
#        'name': 'r_Chi2',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'The number of data points used to fit the phase curve (r band).',
#        'name': 'r_Ndata',
#        'type': ['null', 'int']},
#       {'default': None,
#        'doc': 'Best fit absolute magnitude (i band).',
#        'name': 'i_H',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Best fit G12 slope parameter (i band).',
#        'name': 'i_G12',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of H (i band).',
#        'name': 'i_HErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of G12 (i band).',
#        'name': 'i_G12Err',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'H-G12 covariance (i band).',
#        'name': 'i_H_i_G12_Cov',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Chi^2 statistic of the phase curve fit (i band).',
#        'name': 'i_Chi2',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'The number of data points used to fit the phase curve (i band).',
#        'name': 'i_Ndata',
#        'type': ['null', 'int']},
#       {'default': None,
#        'doc': 'Best fit absolute magnitude (z band).',
#        'name': 'z_H',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Best fit G12 slope parameter (z band).',
#        'name': 'z_G12',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of H (z band).',
#        'name': 'z_HErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of G12 (z band).',
#        'name': 'z_G12Err',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'H-G12 covariance (z band).',
#        'name': 'z_H_z_G12_Cov',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Chi^2 statistic of the phase curve fit (z band).',
#        'name': 'z_Chi2',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'The number of data points used to fit the phase curve (z band).',
#        'name': 'z_Ndata',
#        'type': ['null', 'int']},
#       {'default': None,
#        'doc': 'Best fit absolute magnitude (y band).',
#        'name': 'y_H',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Best fit G12 slope parameter (y band).',
#        'name': 'y_G12',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of H (y band).',
#        'name': 'y_HErr',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Uncertainty of G12 (y band).',
#        'name': 'y_G12Err',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'H-G12 covariance (y band).',
#        'name': 'y_H_y_G12_Cov',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'Chi^2 statistic of the phase curve fit (y band).',
#        'name': 'y_Chi2',
#        'type': ['null', 'float']},
#       {'default': None,
#        'doc': 'The number of data points used to fit the phase curve (y band).',
#        'name': 'y_Ndata',
#        'type': ['null', 'int']},
#       {'default': None,
#        'doc': 'median `extendedness` value from the DIASource.',
#        'name': 'medianExtendedness',
#        'type': ['null', 'float']}]}]},
#   {'default': None, 'name': 'cutoutDifference', 'type': ['null', 'bytes']},
#   {'default': None, 'name': 'cutoutScience', 'type': ['null', 'bytes']},
#   {'default': None, 'name': 'cutoutTemplate', 'type': ['null', 'bytes']}],
#  '__fastavro_parsed': True,
#  '__named_schemas': {'lsst.v7_4.diaSource': {'type': 'record',
#    'name': 'lsst.v7_4.diaSource',
#    'fields': [{'doc': 'Unique identifier of this DiaSource.',
#      'name': 'diaSourceId',
#      'type': 'long'},
#     {'doc': 'Id of the visit where this diaSource was measured.',
#      'name': 'visit',
#      'type': 'long'},
#     {'doc': 'Id of the detector where this diaSource was measured. Datatype short instead of byte because of DB concerns about unsigned bytes.',
#      'name': 'detector',
#      'type': 'int'},
#     {'default': None,
#      'doc': 'Id of the diaObject this source was associated with, if any. If not, it is set to NULL (each diaSource will be associated with either a diaObject or ssObject).',
#      'name': 'diaObjectId',
#      'type': ['null', 'long']},
#     {'default': None,
#      'doc': 'Id of the ssObject this source was associated with, if any. If not, it is set to NULL (each diaSource will be associated with either a diaObject or ssObject).',
#      'name': 'ssObjectId',
#      'type': ['null', 'long']},
#     {'default': None,
#      'doc': 'Id of the parent diaSource this diaSource has been deblended from, if any.',
#      'name': 'parentDiaSourceId',
#      'type': ['null', 'long']},
#     {'doc': 'Effective mid-visit time for this diaSource, expressed as Modified Julian Date, International Atomic Time.',
#      'name': 'midpointMjdTai',
#      'type': 'double'},
#     {'doc': 'Right ascension coordinate of the center of this diaSource.',
#      'name': 'ra',
#      'type': 'double'},
#     {'default': None,
#      'doc': 'Uncertainty of ra.',
#      'name': 'raErr',
#      'type': ['null', 'float']},
#     {'doc': 'Declination coordinate of the center of this diaSource.',
#      'name': 'dec',
#      'type': 'double'},
#     {'default': None,
#      'doc': 'Uncertainty of dec.',
#      'name': 'decErr',
#      'type': ['null', 'float']},
#     {'default': None,
#      'doc': 'Covariance between ra and dec.',
#      'name': 'ra_dec_Cov',
#      'type': ['null', 'float']},
#     {'doc': 'x position computed by a centroiding algorithm.',
#      'name': 'x',
#      'type': 'float'},
# ...
#          'name': 'r_psfFluxMean',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard error of r_psfFluxMean.',
#          'name': 'r_psfFluxMeanErr',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard deviation of the distribution of r_psfFlux.',
#          'name': 'r_psfFluxSigma',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Chi^2 statistic for the scatter of r_psfFlux around r_psfFluxMean.',
#          'name': 'r_psfFluxChi2',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'The number of data points used to compute r_psfFluxChi2.',
#          'name': 'r_psfFluxNdata',
#          'type': ['null', 'int']},
#         {'default': None,
#          'doc': 'Weighted mean forced photometry flux for r filter.',
#          'name': 'r_fpFluxMean',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard error of r_fpFluxMean.',
#          'name': 'r_fpFluxMeanErr',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard deviation of the distribution of r_fpFlux.',
#          'name': 'r_fpFluxSigma',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Weighted mean point-source model magnitude for i filter.',
#          'name': 'i_psfFluxMean',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard error of i_psfFluxMean.',
#          'name': 'i_psfFluxMeanErr',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard deviation of the distribution of i_psfFlux.',
#          'name': 'i_psfFluxSigma',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Chi^2 statistic for the scatter of i_psfFlux around i_psfFluxMean.',
#          'name': 'i_psfFluxChi2',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'The number of data points used to compute i_psfFluxChi2.',
#          'name': 'i_psfFluxNdata',
#          'type': ['null', 'int']},
#         {'default': None,
#          'doc': 'Weighted mean forced photometry flux for i filter.',
#          'name': 'i_fpFluxMean',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard error of i_fpFluxMean.',
#          'name': 'i_fpFluxMeanErr',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard deviation of the distribution of i_fpFlux.',
#          'name': 'i_fpFluxSigma',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Weighted mean point-source model magnitude for z filter.',
#          'name': 'z_psfFluxMean',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard error of z_psfFluxMean.',
#          'name': 'z_psfFluxMeanErr',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard deviation of the distribution of z_psfFlux.',
#          'name': 'z_psfFluxSigma',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Chi^2 statistic for the scatter of z_psfFlux around z_psfFluxMean.',
#          'name': 'z_psfFluxChi2',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'The number of data points used to compute z_psfFluxChi2.',
#          'name': 'z_psfFluxNdata',
#          'type': ['null', 'int']},
#         {'default': None,
#          'doc': 'Weighted mean forced photometry flux for z filter.',
#          'name': 'z_fpFluxMean',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard error of z_fpFluxMean.',
#          'name': 'z_fpFluxMeanErr',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard deviation of the distribution of z_fpFlux.',
#          'name': 'z_fpFluxSigma',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Weighted mean point-source model magnitude for y filter.',
#          'name': 'y_psfFluxMean',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard error of y_psfFluxMean.',
#          'name': 'y_psfFluxMeanErr',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard deviation of the distribution of y_psfFlux.',
#          'name': 'y_psfFluxSigma',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Chi^2 statistic for the scatter of y_psfFlux around y_psfFluxMean.',
#          'name': 'y_psfFluxChi2',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'The number of data points used to compute y_psfFluxChi2.',
#          'name': 'y_psfFluxNdata',
#          'type': ['null', 'int']},
#         {'default': None,
#          'doc': 'Weighted mean forced photometry flux for y filter.',
#          'name': 'y_fpFluxMean',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard error of y_fpFluxMean.',
#          'name': 'y_fpFluxMeanErr',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Standard deviation of the distribution of y_fpFlux.',
#          'name': 'y_fpFluxSigma',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Id of the closest nearby object.',
#          'name': 'nearbyObj1',
#          'type': ['null', 'long']},
#         {'default': None,
#          'doc': 'Distance to nearbyObj1.',
#          'name': 'nearbyObj1Dist',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Natural log of the probability that the observed diaObject is the same as the nearbyObj1.',
#          'name': 'nearbyObj1LnP',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Id of the second-closest nearby object.',
#          'name': 'nearbyObj2',
#          'type': ['null', 'long']},
#         {'default': None,
#          'doc': 'Distance to nearbyObj2.',
#          'name': 'nearbyObj2Dist',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Natural log of the probability that the observed diaObject is the same as the nearbyObj2.',
#          'name': 'nearbyObj2LnP',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Id of the third-closest nearby object.',
#          'name': 'nearbyObj3',
#          'type': ['null', 'long']},
#         {'default': None,
#          'doc': 'Distance to nearbyObj3.',
#          'name': 'nearbyObj3Dist',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Natural log of the probability that the observed diaObject is the same as the nearbyObj3.',
#          'name': 'nearbyObj3LnP',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Mean of the u band flux errors.',
#          'name': 'u_psfFluxErrMean',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Mean of the g band flux errors.',
#          'name': 'g_psfFluxErrMean',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Mean of the r band flux errors.',
#          'name': 'r_psfFluxErrMean',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Mean of the i band flux errors.',
#          'name': 'i_psfFluxErrMean',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Mean of the z band flux errors.',
#          'name': 'z_psfFluxErrMean',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Mean of the y band flux errors.',
#          'name': 'y_psfFluxErrMean',
#          'type': ['null', 'float']}]}]},
#     {'default': None,
#      'name': 'ssObject',
#      'type': ['null',
#       {'type': 'record',
#        'name': 'lsst.v7_4.ssObject',
#        'fields': [{'doc': 'Unique identifier.',
#          'name': 'ssObjectId',
#          'type': 'long'},
#         {'default': None,
#          'doc': 'The date the LSST first linked and submitted the discovery observations to the MPC. May be NULL if not an LSST discovery. The date format will follow general LSST conventions (MJD TAI, at the moment).',
#          'name': 'discoverySubmissionDate',
#          'type': ['null', 'double']},
#         {'default': None,
#          'doc': 'The time of the first LSST observation of this object (could be precovered) as Modified Julian Date, International Atomic Time.',
#          'name': 'firstObservationDate',
#          'type': ['null', 'double']},
#         {'default': None,
#          'doc': 'Arc of LSST observations.',
#          'name': 'arc',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Number of LSST observations of this object.',
#          'name': 'numObs',
#          'type': ['null', 'int']},
#         {'default': None,
#          'doc': 'Minimum orbit intersection distance to Earth.',
#          'name': 'MOID',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'True anomaly of the MOID point.',
#          'name': 'MOIDTrueAnomaly',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Ecliptic longitude of the MOID point.',
#          'name': 'MOIDEclipticLongitude',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'DeltaV at the MOID point.',
#          'name': 'MOIDDeltaV',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Best fit absolute magnitude (u band).',
#          'name': 'u_H',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Best fit G12 slope parameter (u band).',
#          'name': 'u_G12',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Uncertainty of H (u band).',
#          'name': 'u_HErr',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Uncertainty of G12 (u band).',
#          'name': 'u_G12Err',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'H-G12 covariance (u band).',
#          'name': 'u_H_u_G12_Cov',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Chi^2 statistic of the phase curve fit (u band).',
#          'name': 'u_Chi2',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'The number of data points used to fit the phase curve (u band).',
#          'name': 'u_Ndata',
#          'type': ['null', 'int']},
#         {'default': None,
#          'doc': 'Best fit absolute magnitude (g band).',
#          'name': 'g_H',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Best fit G12 slope parameter (g band).',
#          'name': 'g_G12',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Uncertainty of H (g band).',
#          'name': 'g_HErr',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Uncertainty of G12 (g band).',
#          'name': 'g_G12Err',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'H-G12 covariance (g band).',
#          'name': 'g_H_g_G12_Cov',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Chi^2 statistic of the phase curve fit (g band).',
#          'name': 'g_Chi2',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'The number of data points used to fit the phase curve (g band).',
#          'name': 'g_Ndata',
#          'type': ['null', 'int']},
#         {'default': None,
#          'doc': 'Best fit absolute magnitude (r band).',
#          'name': 'r_H',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Best fit G12 slope parameter (r band).',
#          'name': 'r_G12',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Uncertainty of H (r band).',
#          'name': 'r_HErr',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Uncertainty of G12 (r band).',
#          'name': 'r_G12Err',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'H-G12 covariance (r band).',
#          'name': 'r_H_r_G12_Cov',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Chi^2 statistic of the phase curve fit (r band).',
#          'name': 'r_Chi2',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'The number of data points used to fit the phase curve (r band).',
#          'name': 'r_Ndata',
#          'type': ['null', 'int']},
#         {'default': None,
#          'doc': 'Best fit absolute magnitude (i band).',
#          'name': 'i_H',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Best fit G12 slope parameter (i band).',
#          'name': 'i_G12',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Uncertainty of H (i band).',
#          'name': 'i_HErr',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Uncertainty of G12 (i band).',
#          'name': 'i_G12Err',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'H-G12 covariance (i band).',
#          'name': 'i_H_i_G12_Cov',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Chi^2 statistic of the phase curve fit (i band).',
#          'name': 'i_Chi2',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'The number of data points used to fit the phase curve (i band).',
#          'name': 'i_Ndata',
#          'type': ['null', 'int']},
#         {'default': None,
#          'doc': 'Best fit absolute magnitude (z band).',
#          'name': 'z_H',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Best fit G12 slope parameter (z band).',
#          'name': 'z_G12',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Uncertainty of H (z band).',
#          'name': 'z_HErr',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Uncertainty of G12 (z band).',
#          'name': 'z_G12Err',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'H-G12 covariance (z band).',
#          'name': 'z_H_z_G12_Cov',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Chi^2 statistic of the phase curve fit (z band).',
#          'name': 'z_Chi2',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'The number of data points used to fit the phase curve (z band).',
#          'name': 'z_Ndata',
#          'type': ['null', 'int']},
#         {'default': None,
#          'doc': 'Best fit absolute magnitude (y band).',
#          'name': 'y_H',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Best fit G12 slope parameter (y band).',
#          'name': 'y_G12',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Uncertainty of H (y band).',
#          'name': 'y_HErr',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Uncertainty of G12 (y band).',
#          'name': 'y_G12Err',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'H-G12 covariance (y band).',
#          'name': 'y_H_y_G12_Cov',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'Chi^2 statistic of the phase curve fit (y band).',
#          'name': 'y_Chi2',
#          'type': ['null', 'float']},
#         {'default': None,
#          'doc': 'The number of data points used to fit the phase curve (y band).',
#          'name': 'y_Ndata',
#          'type': ['null', 'int']},
#         {'default': None,
#          'doc': 'median `extendedness` value from the DIASource.',
#          'name': 'medianExtendedness',
#          'type': ['null', 'float']}]}]},
#     {'default': None, 'name': 'cutoutDifference', 'type': ['null', 'bytes']},
#     {'default': None, 'name': 'cutoutScience', 'type': ['null', 'bytes']},
#     {'default': None, 'name': 'cutoutTemplate', 'type': ['null', 'bytes']}]}}}

# %%
packet.simulate.simulate_alert(schem.definition)
# Out:
# {'alertId': 1843213837121355684,
#  'diaSource': {'diaSourceId': -8778672038334143001,
#   'visit': 443119330007188748,
#   'detector': -2069236051,
#   'diaObjectId': None,
#   'ssObjectId': None,
#   'parentDiaSourceId': None,
#   'midpointMjdTai': 0.09204287053023008,
#   'ra': 0.7537751377178844,
#   'raErr': None,
#   'dec': 0.7328965668208586,
#   'decErr': None,
#   'ra_dec_Cov': None,
#   'x': 0.9964846968650818,
#   'xErr': None,
#   'y': 0.999973714351654,
#   'yErr': None,
#   'x_y_Cov': None,
#   'centroid_flag': None,
#   'apFlux': None,
#   'apFluxErr': None,
#   'apFlux_flag': None,
#   'apFlux_flag_apertureTruncated': None,
#   'is_negative': None,
#   'snr': None,
#   'psfFlux': None,
#   'psfFluxErr': None,
#   'psfRa': None,
#   'psfRaErr': None,
#   'psfDec': None,
#   'psfDecErr': None,
#   'psfFlux_psfRa_Cov': None,
#   'psfFlux_psfDec_Cov': None,
#   'psfRa_psfDec_Cov': None,
#   'psfLnL': None,
#   'psfChi2': None,
#   'psfNdata': None,
#   'psfFlux_flag': None,
#   'psfFlux_flag_edge': None,
#   'psfFlux_flag_noGoodPixels': None,
#   'trailFlux': None,
#   'trailFluxErr': None,
#   'trailRa': None,
#   'trailRaErr': None,
#   'trailDec': None,
#   'trailDecErr': None,
#   'trailLength': None,
#   'trailLengthErr': None,
#   'trailAngle': None,
#   'trailAngleErr': None,
#   'trailFlux_trailRa_Cov': None,
#   'trailFlux_trailDec_Cov': None,
#   'trailFlux_trailLength_Cov': None,
#   'trailFlux_trailAngle_Cov': None,
#   'trailRa_trailDec_Cov': None,
#   'trailRa_trailLength_Cov': None,
#   'trailRa_trailAngle_Cov': None,
#   'trailDec_trailLength_Cov': None,
#   'trailDec_trailAngle_Cov': None,
#   'trailLength_trailAngle_Cov': None,
#   'trailLnL': None,
#   'trailChi2': None,
#   'trailNdata': None,
#   'trail_flag_edge': None,
#   'dipoleMeanFlux': None,
#   'dipoleMeanFluxErr': None,
#   'dipoleFluxDiff': None,
#   'dipoleFluxDiffErr': None,
#   'dipoleRa': None,
#   'dipoleRaErr': None,
#   'dipoleDec': None,
#   'dipoleDecErr': None,
#   'dipoleLength': None,
#   'dipoleLengthErr': None,
#   'dipoleAngle': None,
#   'dipoleAngleErr': None,
#   'dipoleMeanFlux_dipoleFluxDiff_Cov': None,
#   'dipoleMeanFlux_dipoleRa_Cov': None,
#   'dipoleMeanFlux_dipoleDec_Cov': None,
#   'dipoleMeanFlux_dipoleLength_Cov': None,
#   'dipoleMeanFlux_dipoleAngle_Cov': None,
#   'dipoleFluxDiff_dipoleRa_Cov': None,
#   'dipoleFluxDiff_dipoleDec_Cov': None,
#   'dipoleFluxDiff_dipoleLength_Cov': None,
#   'dipoleFluxDiff_dipoleAngle_Cov': None,
#   'dipoleRa_dipoleDec_Cov': None,
#   'dipoleRa_dipoleLength_Cov': None,
#   'dipoleRa_dipoleAngle_Cov': None,
#   'dipoleDec_dipoleLength_Cov': None,
#   'dipoleDec_dipoleAngle_Cov': None,
#   'dipoleLength_dipoleAngle_Cov': None,
#   'dipoleLnL': None,
#   'dipoleChi2': None,
#   'dipoleNdata': None,
#   'forced_PsfFlux_flag': None,
#   'forced_PsfFlux_flag_edge': None,
#   'forced_PsfFlux_flag_noGoodPixels': None,
#   'snapDiffFlux': None,
#   'snapDiffFluxErr': None,
#   'fpBkgd': None,
#   'fpBkgdErr': None,
#   'ixx': None,
#   'ixxErr': None,
#   'iyy': None,
#   'iyyErr': None,
#   'ixy': None,
#   'ixyErr': None,
#   'ixx_iyy_Cov': None,
#   'ixx_ixy_Cov': None,
#   'iyy_ixy_Cov': None,
#   'ixxPSF': None,
#   'iyyPSF': None,
#   'ixyPSF': None,
#   'shape_flag': None,
#   'shape_flag_no_pixels': None,
#   'shape_flag_not_contained': None,
#   'shape_flag_parent_source': None,
#   'extendedness': None,
#   'reliability': None,
#   'band': None,
#   'dipoleFitAttempted': None,
#   'pixelFlags': None,
#   'pixelFlags_bad': None,
#   'pixelFlags_cr': None,
#   'pixelFlags_crCenter': None,
#   'pixelFlags_edge': None,
#   'pixelFlags_nodata': None,
#   'pixelFlags_nodataCenter': None,
#   'pixelFlags_interpolated': None,
#   'pixelFlags_interpolatedCenter': None,
#   'pixelFlags_offimage': None,
#   'pixelFlags_saturated': None,
#   'pixelFlags_saturatedCenter': None,
#   'pixelFlags_suspect': None,
#   'pixelFlags_suspectCenter': None,
#   'pixelFlags_streak': None,
#   'pixelFlags_streakCenter': None,
#   'pixelFlags_injected': None,
#   'pixelFlags_injectedCenter': None,
#   'pixelFlags_injected_template': None,
#   'pixelFlags_injected_templateCenter': None},
#  'prvDiaSources': None,
#  'prvDiaForcedSources': None,
#  'prvDiaNondetectionLimits': None,
#  'diaObject': None,
#  'ssObject': None,
#  'cutoutDifference': None,
#  'cutoutScience': None,
#  'cutoutTemplate': None}

# %%
client = makeClient("base_efd",)
start = Time("2025-08-22T20:30:16.20")
end = Time("2025-10-29T17:20")

# %%
# client.get_fields()
a = await client.get_topics()

# %%
for entry in a:
    if entry.lower().__contains__("header"):
        print(entry)
# Out:
# lsst.sal.ATHeaderService.ackcmd
# lsst.sal.ATHeaderService.command_disable
# lsst.sal.ATHeaderService.command_enable
# lsst.sal.ATHeaderService.command_exitControl
# lsst.sal.ATHeaderService.command_setLogLevel
# lsst.sal.ATHeaderService.command_standby
# lsst.sal.ATHeaderService.command_start
# lsst.sal.ATHeaderService.logevent_authList
# lsst.sal.ATHeaderService.logevent_errorCode
# lsst.sal.ATHeaderService.logevent_heartbeat
# lsst.sal.ATHeaderService.logevent_largeFileObjectAvailable
# lsst.sal.ATHeaderService.logevent_logLevel
# lsst.sal.ATHeaderService.logevent_logMessage
# lsst.sal.ATHeaderService.logevent_simulationMode
# lsst.sal.ATHeaderService.logevent_softwareVersions
# lsst.sal.ATHeaderService.logevent_summaryState
# lsst.sal.CCHeaderService.ackcmd
# lsst.sal.CCHeaderService.command_disable
# lsst.sal.CCHeaderService.command_enable
# lsst.sal.CCHeaderService.command_exitControl
# lsst.sal.CCHeaderService.command_standby
# lsst.sal.CCHeaderService.command_start
# lsst.sal.CCHeaderService.logevent_authList
# lsst.sal.CCHeaderService.logevent_errorCode
# lsst.sal.CCHeaderService.logevent_heartbeat
# lsst.sal.CCHeaderService.logevent_largeFileObjectAvailable
# lsst.sal.CCHeaderService.logevent_logLevel
# lsst.sal.CCHeaderService.logevent_logMessage
# lsst.sal.CCHeaderService.logevent_simulationMode
# lsst.sal.CCHeaderService.logevent_softwareVersions
# lsst.sal.CCHeaderService.logevent_summaryState
# lsst.sal.GCHeaderService.ackcmd
# lsst.sal.GCHeaderService.command_disable
# lsst.sal.GCHeaderService.command_enable
# lsst.sal.GCHeaderService.command_exitControl
# lsst.sal.GCHeaderService.command_standby
# lsst.sal.GCHeaderService.command_start
# lsst.sal.GCHeaderService.logevent_authList
# lsst.sal.GCHeaderService.logevent_errorCode
# lsst.sal.GCHeaderService.logevent_heartbeat
# lsst.sal.GCHeaderService.logevent_largeFileObjectAvailable
# lsst.sal.GCHeaderService.logevent_logLevel
# lsst.sal.GCHeaderService.logevent_logMessage
# lsst.sal.GCHeaderService.logevent_simulationMode
# lsst.sal.GCHeaderService.logevent_softwareVersions
# lsst.sal.GCHeaderService.logevent_summaryState
# lsst.sal.MTHeaderService.ackcmd
# lsst.sal.MTHeaderService.command_disable
# lsst.sal.MTHeaderService.command_enable
# lsst.sal.MTHeaderService.command_exitControl
# lsst.sal.MTHeaderService.command_standby
# lsst.sal.MTHeaderService.command_start
# lsst.sal.MTHeaderService.logevent_errorCode
# lsst.sal.MTHeaderService.logevent_heartbeat
# lsst.sal.MTHeaderService.logevent_largeFileObjectAvailable
# lsst.sal.MTHeaderService.logevent_logLevel
# lsst.sal.MTHeaderService.logevent_logMessage
# lsst.sal.MTHeaderService.logevent_simulationMode
# lsst.sal.MTHeaderService.logevent_softwareVersions
# lsst.sal.MTHeaderService.logevent_summaryState

# %%
def parseAlertContents(inputList,dictionary):
    """
    A function to resolve alert contents from the header file of an acquired image
    """

    dictionary["diaSource"]["ra"] = getRA(inputList)
    dictionary["diaSource"]["dec"] = getDec(inputList)
    dictionary["observation_reason"] = getObsReason(inputList)
    dictionary["target_name"] = getTargetName(inputList)
    sourceID = generateSourceID()
    dictionary["diaSourceId"] = sourceID
    dictionary["diaSource"]["diaSourceId"] = sourceID

    return dictionary

def generateSourceID():
    return np.random.randint(9223372036854775808,dtype=np.int64)

def getRA(inputList):

    raStart = float(getCoordFromKeyword("RASTART",inputList))
    raEnd = float(getCoordFromKeyword("RAEND",inputList))

    avgCenterRa = np.mean([raStart,raEnd]) # Take the average of the two for now

    if np.random.randint(0,2):
        return avgCenterRa+np.random.random()*1.75
    else:
        return avgCenterRa-np.random.random()*1.75

def getDec(inputList):

    decStart = float(getCoordFromKeyword("DECSTART",inputList))
    decEnd = float(getCoordFromKeyword("DECEND",inputList))

    avgCenterDec = np.mean([decStart,decEnd]) # Take the average of the two for now

    if np.random.randint(0,2):
        return avgCenterDec+np.random.random()*1.75
    else:
        return avgCenterDec-np.random.random()*1.75

def getObsReason(inputList):
    obsReasons = getCoordFromKeyword("REASON",inputList,returnAll=True)

    returnString = ""
    for k in obsReasons[3:]:
        returnString+=k
        if k!=obsReasons[-1]:
            returnString+=", "

    return returnString

def getTargetName(inputList):
    
    obsReasons = getCoordFromKeyword("COMMENT",inputList,returnAll=True)

    returnString = ""
    for k in obsReasons[3:]:
        returnString+=k
        if k!=obsReasons[-1]:
            returnString+=", "

    return returnString

def getCoordFromKeyword(keyword,inputList,index=-1,returnAll=False):
    msk = ["keyword: {}".format(keyword) in s for s in inputList]
    firstIndex = np.argwhere(inputList==inputList[msk][0])[0][0]
    if returnAll:
        return inputList[firstIndex+1].split(" ")
    else:
        return inputList[firstIndex+1].split(" ")[index]

# %%
topic = "lsst.sal.MTHeaderService.logevent_largeFileObjectAvailable"
result = (await getDataFrame(client,[np.datetime64(start.to_datetime())],[np.datetime64(end.to_datetime())],topic)).sort_index()

yml = urllib.request.urlopen(result.iloc[-1]['url']).read().decode()
fullList = np.array(yml.split("\n"))
# Out:
# Starting query for time range 2025-08-22T20:30:16.200000 - 2025-10-29T17:20:00.000000 . . . Finished
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/urllib/request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/http/client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/http/client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1383     body = _encode(body, 'body')
# -> 1384 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/http/client.py:1333, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1332     raise CannotSendHeader()
# -> 1333 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/http/client.py:1093, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1092 del self._buffer[:]
# -> 1093 self.send(msg)
#    1095 if message_body is not None:
#    1096
#    1097     # create a consistent interface to message_body
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/http/client.py:1037, in HTTPConnection.send(self, data)
#    1036 if self.auto_open:
# -> 1037     self.connect()
#    1038 else:
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/http/client.py:1472, in HTTPSConnection.connect(self)
#    1470 "Connect to a host on a given (SSL) port."
# -> 1472 super().connect()
#    1474 if self._tunnel_host:
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/http/client.py:1013, in HTTPConnection.connect(self)
#    1012 if self._tunnel_host:
# -> 1013     self._tunnel()
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/http/client.py:981, in HTTPConnection._tunnel(self)
#     980         self.close()
# --> 981         raise OSError(f"Tunnel connection failed: {code} {message.strip()}")
#     983 finally:
#
# OSError: Tunnel connection failed: 503 Service Unavailable
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[10], line 4
#       1 topic = "lsst.sal.MTHeaderService.logevent_largeFileObjectAvailable"
#       2 result = (await getDataFrame(client,[np.datetime64(start.to_datetime())],[np.datetime64(end.to_datetime())],topic)).sort_index()
# ----> 4 yml = urllib.request.urlopen(result.iloc[-1]['url']).read().decode()
#       5 fullList = np.array(yml.split("\n"))
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/urllib/request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/urllib/request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/urllib/request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/urllib/request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/urllib/request.py:1392, in HTTPSHandler.https_open(self, req)
#    1391 def https_open(self, req):
# -> 1392     return self.do_open(http.client.HTTPSConnection, req,
#    1393                         context=self._context)
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0/lib/python3.12/urllib/request.py:1347, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1344         h.request(req.get_method(), req.selector, req.data, headers,
#    1345                   encode_chunked=req.has_header('Transfer-encoding'))
#    1346     except OSError as err: # timeout error
# -> 1347         raise URLError(err)
#    1348     r = h.getresponse()
#    1349 except:
#
# URLError: <urlopen error Tunnel connection failed: 503 Service Unavailable>

# %%
# %%time

myDictionary = {"diaSource":{}}
for k in np.arange(1000):
    resultDictionary = parseAlertContents(fullList,myDictionary)

# %%
resultDictionary
