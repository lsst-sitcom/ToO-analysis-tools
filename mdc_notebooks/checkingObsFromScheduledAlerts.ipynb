# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
testPath = "~/too_mdc/data/strategyResults/preliminary/20878_10350_0/observations.csv"

# %%
obsDF = pd.read_csv(testPath)

# %%
msk = [x.lower().__contains__("too") for x in obsDF["observation_reason"]]

# %%
for __,row in obsDF[msk].iterrows():
    print(row["note"].split(","))
# Out:
# ['ToO', ' neutrino', ' 1_t0_i1', ' 111']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 112']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 113']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 114']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 115']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 116']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 117']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 118']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 119']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 120']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 121']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 122']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 123']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 124']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 125']
# ['ToO', ' neutrino', ' 1_t0_i1', ' 126']
# ['ToO', ' neutrino', ' 1_t0_i3', ' 140']
# ['ToO', ' neutrino', ' 1_t0_i3', ' 141']
# ['ToO', ' neutrino', ' 1_t0_i3', ' 142']
# ['ToO', ' neutrino', ' 1_t0_i3', ' 143']
# ['ToO', ' neutrino', ' 1_t0_i2', ' 148']
# ['ToO', ' neutrino', ' 1_t0_i2', ' 149']
# ['ToO', ' neutrino', ' 1_t0_i2', ' 150']
# ...
