# %%
import numpy as np
import healpy as hp
import pandas as pd

# %%
eventName = "S250929ad"
prelimObsPath = "~/too_mdc/data/strategyResults/preliminary"
observationsCSVPath = os.path.join(prelimObsPath,eventName,"observations.csv")

# %%
obsDF = pd.read_csv(observationsCSVPath)

# %%
ToOMask = [x.__contains__("ToO") for x in obsDF["observation_reason"]]

# %%
obsDF[ToOMask]
# Out:
#       Unnamed: 0    ID        RA       dec           mjd  flush_by_mjd  \
# 721          721   721  2.039459  0.279310  60969.317577  60971.187437
# 722          722   722  2.040034  0.310726  60969.318027  60971.187437
# 723          723   723  2.062566  0.267635  60969.318478  60971.187437
# 724          724   724  2.073820  0.263296  60969.318922  60971.187437
# 725          725   725  2.089763  0.286234  60969.319373  60971.187437
# ...          ...   ...       ...       ...           ...           ...
# 3176        3176  3176  6.229587 -0.171337  60973.266625  60974.909705
# 3177        3177  3177  6.250042 -0.175764  60973.267075  60974.909705
# 3178        3178  3178  6.258234 -0.152872  60973.267522  60974.909705
# 3380        3380  3380  2.867544 -0.203589  60973.372266  60973.993661
# 3381        3381  3381  2.920541 -0.312276  60973.372726  60973.993661
#
#       exptime band filter  rotSkyPos  ...    moonRA   moonDec  moonDist  \
# ...
